# %% [markdown]
# # PyTorch: Initialization Methods

# %% [markdown]
# One thing to explore to see if I can't get out of the 0.693 DEATH VALLEY...

# %%
import audiomod
import ptmod

import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt
# import seaborn as sns
# plt.style.use('seaborn')

from functools import partial
from copy import deepcopy
import pickle

# %matplotlib inline

# %%
seed_gen = torch.manual_seed(23)
torch.initial_seed()
# Out:
# 23

# %% [markdown]
# ## Setup

# %%
sax1203_dg = audiomod.pull_datagroup_from_db('sax1203')

# %%
sax_train, sax_test = audiomod.tts(sax1203_dg)

# %%
train_ds = ptmod.SpectroDataset(sax_train, scaling=0.25)
test_ds = ptmod.SpectroDataset(sax_test, scaling=0.25)

# %% [markdown]
# ## Init

# %% [markdown]
# A whole bunch of initialization functions that can be passed to `.apply()` to do their things.

# %%
def check_weights(m):
    print(m)
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        print("\nNumber of weight variables:", len(m.weight))
        for v in m.weight:
            print("\nMean:", v.data.mean())
            print("Std:", v.data.std())
            print("Dimensions:", v.data.ndimension())
    print("\n---\n")

# %%
def init_ones(m):
    print(m)
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        for v in m.weight:
            nn.init.constant(v, 1)
        print(m.weight)

# %%
def init_norm(m, mean=0, std=1):
    print(m)
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        for v in m.weight:
            nn.init.normal(v, mean=mean, std=std)
        print(m.weight)

# %%
def init_uni(m, a=0, b=1):
    print(m)
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        for v in m.weight:
            nn.init.uniform(v, a=a, b=b)
        print(m.weight)

# %%
def init_xav_norm(m, gain=nn.init.calculate_gain('relu')):
    """Only for convolution layers, where weight tensors are 3D"""
    seed_gen = torch.manual_seed(23)
    print(m)
    if isinstance(m, nn.Conv2d):
        for v in m.weight:
            nn.init.xavier_normal(v, gain=gain)
        print(m.weight)

# %%
def init_xav_uni(m, gain=nn.init.calculate_gain('relu')):
    """Only for convolution layers, where weight tensors are 3D"""
    seed_gen = torch.manual_seed(23)
    print(m)
    if isinstance(m, nn.Conv2d):
        for v in m.weight:
            nn.init.xavier_uniform(v, gain=gain)
        print(m.weight)

# %%
def init_norm_auto(m):
    """Based on self.reset_parameters() in nn.Linear and nn.Conv2n"""
    seed_gen = torch.manual_seed(23)
    # print(m)
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        if isinstance(m, nn.Conv2d):
            n = m.in_channels
            for k in m.kernel_size:
                n *= k
        if isinstance(m, nn.Linear):
            n = m.weight.size(1)
        std = 1. / np.sqrt(n)
        m.weight.data.normal_(mean=0, std=std)
        # print(m.weight)

# %% [markdown]
# Try 'em out below:

# %%
params = {
    'c1': [5,2,10],
    'p1': [2,2],
    'c2': [5,2,20],
    'p2': [2,2],
    'f1': [700,100],
    'f2': [100,2]
}

# %%
cnn_test = ptmod.CNN_cpcpff(params)

# %%
cnn_test.apply(check_weights)
# Out:
# Conv2d(1, 10, kernel_size=(5, 5), stride=(2, 2))
#
# Number of weight variables: 10
#
# Mean: -0.015132528664544224
# Std: 0.21811257034980172
# Dimensions: 3
#
# Mean: 0.05179643907118589
# Std: 0.20803878548480093
# Dimensions: 3
#
# Mean: -0.018625109121203423
# Std: 0.20626533429662186
# Dimensions: 3
#
# Mean: -0.03366573915642221
# Std: 0.21036013568227915
# Dimensions: 3
#
# Mean: 0.05743596957996488
# Std: 0.2071027104605339
# Dimensions: 3
#
# Mean: 0.03357626121491194
# Std: 0.23690357343006566
# Dimensions: 3
#
# Mean: 0.01646064016968012
# Std: 0.20282516725087724
# Dimensions: 3
#
# Mean: -0.023105934746563434
# Std: 0.21450259003892214
# Dimensions: 3
#
# Mean: -0.02120270038023591
# Std: 0.16509413848798968
# Dimensions: 3
#
# Mean: -0.05459213100373745
# Std: 0.12605178332404404
# Dimensions: 3
#
# ---
#
# MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#
# ---
#
# Conv2d(10, 20, kernel_size=(5, 5), stride=(2, 2))
#
# Number of weight variables: 20
#
# Mean: -0.00022309319907799362
# Std: 0.06366714319628283
# Dimensions: 3
#
# Mean: -0.000144376871176064
# Std: 0.06364751452796778
# Dimensions: 3
#
# Mean: 0.0010908254203386605
# Std: 0.06788196206056339
# Dimensions: 3
#
# Mean: 0.005153659432049608
# Std: 0.06338690614162154
# Dimensions: 3
#
# Mean: 0.0038229662383091638
# Std: 0.06531434329899574
# Dimensions: 3
#
# Mean: 0.0075007127687567845
# Std: 0.06380325495076722
# Dimensions: 3
#
# Mean: 0.0014861841176170855
# Std: 0.06417056963294306
# Dimensions: 3
#
# Mean: 0.0010787526972126215
# Std: 0.05788079379585036
# Dimensions: 3
#
# Mean: -0.0016698345125769265
# Std: 0.06872805909146434
# Dimensions: 3
#
# Mean: 0.00634291438254877
# Std: 0.06471688302282741
# Dimensions: 3
#
# Mean: 0.0016989169379230588
# Std: 0.06282174265526298
# Dimensions: 3
#
# Mean: -0.0035550971665797987
# Std: 0.06012380722863933
# Dimensions: 3
#
# Mean: 7.074566604569554e-05
# Std: 0.06560504991143176
# Dimensions: 3
#
# Mean: -0.00240578177533132
# Std: 0.05969742040034225
# Dimensions: 3
#
# Mean: 0.0010091711537097581
# Std: 0.060924159309549766
# Dimensions: 3
#
# Mean: -0.001600954326801002
# Std: 0.062371416709442885
# Dimensions: 3
#
# Mean: 0.002669418007542845
# Std: 0.06332814724855193
# Dimensions: 3
#
# Mean: -0.002087371542584151
# Std: 0.06297470659159364
# Dimensions: 3
#
# Mean: -0.002429169221082702
# Std: 0.06136746128893332
# Dimensions: 3
#
# Mean: -0.0062992584715539125
# Std: 0.06598993362286235
# Dimensions: 3
#
# ---
#
# MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#
# ---
#
# Linear (700 -> 100)
#
# Number of weight variables: 100
#
# Mean: 3.23951543811875e-05
# Std: 0.038957318578015765
# Dimensions: 1
#
# Mean: 0.0034771708547590868
# Std: 0.0371975759239769
# Dimensions: 1
#
# Mean: 0.00039020915667996244
# Std: 0.03881349142669049
# Dimensions: 1
#
# Mean: 0.0014321917009121016
# Std: 0.03845165960731414
# Dimensions: 1
#
# Mean: -0.0010104698458487504
# Std: 0.03681735739011666
# Dimensions: 1
#
# Mean: 0.0004170206666386938
# Std: 0.03735659930926638
# Dimensions: 1
#
# Mean: -0.0016615911108237924
# Std: 0.037696189711298664
# Dimensions: 1
#
# Mean: -0.0011129495589809885
# Std: 0.036330224319509316
# Dimensions: 1
#
# Mean: -0.0007297943074507072
# Std: 0.03808037985769968
# Dimensions: 1
#
# Mean: 0.0006567374258572402
# Std: 0.037607640881117045
# Dimensions: 1
#
# Dimensions: 1
#
# Mean: 0.0005845400062701498
# Std: 0.037998046089899554
# Dimensions: 1
#
# Mean: 0.0010351648411025443
# Std: 0.03581169121362142
# Dimensions: 1
#
# Mean: -0.0001701691561694523
# Std: 0.0393882948305482
# Dimensions: 1
#
# Mean: -0.001042577860820789
# Std: 0.03901678903739022
# Dimensions: 1
#
# Mean: -0.0007063192174453953
# Std: 0.0374472387563512
# Dimensions: 1
#
# Mean: -0.0016533765166033326
# Std: 0.0382040206809092
# Dimensions: 1
#
# Mean: -0.00220950309453266
# Std: 0.03748299736868984
# Dimensions: 1
#
# Mean: -0.0008323757275814257
# Std: 0.03916256934468288
# Dimensions: 1
#
# Mean: -0.0015507525747040876
# Std: 0.038883980755624194
# Dimensions: 1
#
# Mean: -0.0004968403678036079
# Std: 0.03835839373547039
# Dimensions: 1
#
# Mean: 0.002731670063991
# Std: 0.03931688342744394
# Dimensions: 1
#
# ---
#
# Linear (100 -> 2)
#
# Number of weight variables: 2
#
# Mean: -0.0019533672338729957
# Std: 0.10507185346913978
# Dimensions: 1
#
# Mean: 0.010545867027249188
# Std: 0.10724079726847414
# Dimensions: 1
#
# ---
#
# CNN_cpcpff (
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(2, 2))
#   (pool1): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(2, 2))
#   (pool2): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (fc1): Linear (700 -> 100)
#   (fc2): Linear (100 -> 2)
# )
#
# ---
# CNN_cpcpff (
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(2, 2))
#   (pool1): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(2, 2))
#   (pool2): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (fc1): Linear (700 -> 100)
#   (fc2): Linear (100 -> 2)
# )

# %%
# create partials to set params, as .apply() only allows for one arg
# init_p = partial(init_norm, mean=-0.5, std=0.5)
# init_p = partial(init_uni, a=-5, b=5)
# init_p = partial(init_xav_norm, gain=1)

# %%
cnn_test.apply(init_norm_auto)
# Out:
# CNN_cpcpff (
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(2, 2))
#   (pool1): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(2, 2))
#   (pool2): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (fc1): Linear (700 -> 100)
#   (fc2): Linear (100 -> 2)
# )

# %%
losses = ptmod.fit(
    cnn_test,
    train_ds, 
    optim.SGD(cnn_test.parameters(), lr=0.01, weight_decay=0.01, momentum=0.8), 
    nn.CrossEntropyLoss(), 
    3,
    8
)
# Out:
# Epoch 1
#  * Avg loss: 0.682	Time: 7474.772 ms
#  * Weights updated: True
# Epoch 2
#  * Avg loss: 0.681	Time: 7683.385 ms
#  * Weights updated: True
# Epoch 3
#  * Avg loss: 0.646	Time: 7234.953 ms
#  * Weights updated: True
#
# Training Complete!

# %% [markdown]
# ### Init methods that do NOT work:
#
# * fill Conv and Linear layers with ones
# * norm (0, 1)
# * norm (0, 0.1)
# * norm (0.1, 0.1)
# * norm (0.5, 0.1)
# * norm (-0.5, 0.5)
# * uniform (-0.5,0.5)
# * uniform (-1, 1)
# * uniform (-1, 0)

# %% [markdown]
# ### Init methods that DO work:
#
# * Built-in (sometimes)
# * `init_norm_auto()` has hope! Like built-in but normal distrib instead of uniform
