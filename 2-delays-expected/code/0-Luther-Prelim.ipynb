# %% [markdown]
# # 0. Luther – Preliminary

# %% [markdown]
# ## Imports & Versions

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import time
import sys

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os
chromedriver = "/Applications/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
# these doesn't all work right now

list_of_imports = [('Numpy', np), 
                   ('Pandas', pd), 
#                   ('Beautiful Soup', BeautifulSoup), 
                   ('Selenium', webdriver)
                  ]

for mod in list_of_imports:
    print(f"{mod[0]}: {mod[1].__version__}")

print("Python:", sys.version)
# Out:
# Numpy: 1.12.1
# Pandas: 0.20.1
# Selenium: 3.6.0
# Python: 3.6.1 |Anaconda 4.4.0 (x86_64)| (default, May 11 2017, 13:04:09)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]

# %% [markdown]
# ## Things For Later

# %%
# if you want to add some random delay between queries:

# delay = np.random.uniform(0.8,3.0)
# time.sleep(delay)

# %%
# create date in YYYYMMDD format, one day previous
today = datetime.now()
one_day = timedelta(days=1)
previous = today - one_day
previous
# Out:
# datetime.datetime(2017, 10, 2, 10, 24, 46, 635160)

# %%
# change flight_num and route_num to args when ready for use

def flight_url_maker(date_str, flight_num='AAL321', route_num='0130Z'):
    """
    Takes datetime object, flight number, and route number, 
    returns URL to search for a particular flight/route/day. 
    ---
    IN: date string YYYYMMDD (str), flight_num (str), route_num (str)
    OUT: search URL (str)
    """

    # base URL constructors
    base_url1 = 'http://flightaware.com/live/flight/'
    base_url2 = '/history/'
    base_url3 = '/KLGA/KORD'
    
    # merge vars with URL bases
    search_url = (base_url1 + flight_num + base_url2 + 
                  date_str + '/' + route_num + base_url3)

    return search_url

# %% [markdown]
# ## Scraping, Take 1

# %% [markdown]
# ### Goal 1: scrape every record of a partiular flight number on the LGA-ORD route back to a certain date

# %% [markdown]
# All the airlines operating flight between LGA and ORD:
# * American
# * United
# * Republic (for American Eagle, Delta Connection, United Express — FA labels as Delta, but all pictures are American livery)
# * SkyWest (for AE, DC, **UE**)
# * Spirit
#
# What info do we want? (italics are bonus):
# * Airline
# * Flight number
# * Date
# * Scheduled arrival time
# * Actual arrival time
# * *Aircraft type*
# * *Average fare*
#
# Key URLs:
# * http://flightaware.com/live/airport/KORD — ORD main, live updates
# * http://flightaware.com/live/airport/KORD/arrivals — ORD arrivals, static (?)
# * http://flightaware.com/live/airport/KORD/arrivals?;offset=0;order=actualarrivaltime;sort=DESC — change the offset in increments of 40 to view arrivals history for one week back
# * http://flightaware.com/live/findflight?origin=KLGA&destination=KORD — LGA-ORD route, no history option, JavaScript (?) sidebar to filter results
# * http://flightaware.com/live/flight/AAL321 — live status on flight in progress
# * http://flightaware.com/live/flight/AAL321/history/500 – complete (listed) history of a particular flight number (number at end can be adjusted to capture all posted records)
# * http://flightaware.com/live/flight/AAL321/history/20170823/0130Z/KLGA/KORD — historic record of specific flight. 0130Z indicates the route number of that flight number. Can change out the route number and date as far back as the records exist (YES). **Scrape this one for info.**
#
# First, check to see if flight was cancelled!

# %%
# could make a class for each route/airline

# %% [markdown]
# Here's the info we want to capture:
#
# Airline, Flight #, Origin, Destination, Date, Arrival (Sched), Arrival (Actual), *Plane Model*, *Avg Price*
#
# If canceled, input 'C' for Arrivals (or just in Actual).

# %% [markdown]
# ### Testing Soup

# %% [markdown]
# The three main conditions one encounters with a flight page:
# * arrived
# * canceled
# * no flight

# %%
arrived_url = 'http://flightaware.com/live/flight/AAL321/history/20170824/0130Z/KLGA/KORD'
canceled_url = 'http://flightaware.com/live/flight/AAL321/history/20170823/0130Z/KLGA/KORD'
noflight_url = 'http://flightaware.com/live/flight/AAL321/history/20160824/0130Z/KLGA/KORD'

# %%
resp_arr = requests.get(arrived_url)
soup_arr = BeautifulSoup(resp_arr.text, 'html5lib')

resp_c = requests.get(canceled_url)
soup_c = BeautifulSoup(resp_c.text, 'html5lib')

resp_nf = requests.get(noflight_url)
soup_nf = BeautifulSoup(resp_nf.text, 'html5lib')

# %%
print(soup_arr.prettify())
# Out:
# <!DOCTYPE html>
# <html class="responsive-full" dir="LTR" lang="en">
#  <!--
# Looking at the source?  Great!
#   FlightAware is looking for UI/UX, web, and backend developers, mathematicians and electrical engineers.
#
# Get in touch with us:
# https://flightaware.com/about/careers
#
# -->
#  <head>
#   <!-- 	Attention! You must agree with FlightAware's Terms of Use at http://flightaware.com/about/termsofuse
#   Data robots and collection agents should use http://flightaware.com/commercial/flightxml/
#             Copyright 2017 FlightAware.  All Rights Reserved. -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="@FlightAware" name="twitter:site"/>
#   <title>
#    American Airlines (AA)  #321 ✈ 23-Aug-2017  ✈ KLGA - KORD ✈ FlightAware
#   </title>
#   <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/>
#   <link href="/opensearch.xml" rel="search" title="FlightAware" type="application/opensearchdescription+xml"/>
#   <link href="http://e0.flightcdn.com/images/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#   <!-- non scripts -->
#   <link href="http://e1.flightcdn.com/include/bff967a4f-flightpage/flightpage.css" rel="stylesheet" type="text/css"/>
#   <link href="http://e0.flightcdn.com/include/0d5859c97-foundation/foundation.css" rel="stylesheet" type="text/css"/>
#   <link href="http://e1.flightcdn.com/include/0d5859c97-flightaware.css" rel="stylesheet" type="text/css"/>
#   <script>
#    if(typeof window.performance === 'object' && typeof window.performance.navigation === 'object' && window.performance.navigation.type == 2) {
# 											location.reload();
# 										}
#   </script>
#   <meta content="AAL" name="airline"/>
#   <meta content="KORD" name="destination"/>
#   <meta content="KLGA" name="origin"/>
#   <meta content="B738" name="aircrafttype"/>
#   <!--[if lt IE 9]>
# <script>
# document.createElement('header');
# document.createElement('nav');
# document.createElement('section');
# document.createElement('article');
# document.createElement('aside');
# document.createElement('footer');
# document.createElement('hgroup');
# </script>
# <![endif]-->
#   <!-- scripts -->
#   <script type="text/javascript">
#    user = {"username":"","TZ":":America/New_York","accounttype":"0","email":"","id":"","locale":"en_US","lang":"en","name":" ","active":"","arincUser":false,"fboUser":false,"distance_units":"sm","airportCode":"","altitudeDisplay":"feet","speedDisplay":"miles","fuelBurnDisplay":"gallons","flightpageLayout":"0","comma":",","decimal":".","adhocEnabled":false};
#   </script>
#   <script type="text/javascript">
#    var FAIntegrationConfig = {"enabled":false,"idents":[]};
#   </script>
#   <script type="text/javascript">
#    var airportNamesUrl = 'http://e0.flightcdn.com/ajax/ignoreall/airport_names_yajl.rvt', airportValidateUrl = 'http://e1.flightcdn.com/ajax/validate_airport.rvt';
#   </script>
#   <script>
#    var rosettaBootstrap = {"FP_Link_All_Flights":"all flights","FP_Tour_The_Page":"Tour the page","FP_Header_Live_Flight_Tracker":"Live Flight Tracker","FP_Notification_Added_Successfully_You":"Success! you will receive status updates for this flight.","FP_Owner":"Owner","FP_Status_Updates_Not_Available":"Status updates are not available for historical flights","FP_Last_Seen_Near":"last seen near","FP_Remark_Add":"Add New Remark","FP_Operator":"Operator","FP_Aviator_View_Explain":"Aviator view shows general aviation flights with runway times in the progress bar and a condensed page layout. Enable this setting to view all flights this way.","FP_Flight":"Flight","FP_Explain_Enter_Flight_Info":"Enter a flight (tail number, identifier, or airline name & number) into the search box above for live flight tracking.","FP_Few_Seconds":"a few seconds","FP_Remark_Added_Successfully":"Remark added successfully.","FP_Tour_Step_2":"Progress bar shows gate-to-gate departures and arrivals (when available)","FP_Duration_Minute":"%1 minute","FP_Manager":"Manager","FP_Tour_Step_1":"We redesigned our Flight Page. Check out the updated features!","FP_AD_Message_TTL":"Please enter a valid number of hours to retry this message for.","FP_X_Flown":"%1 flown","FP_X_To_Go":"%1 to go","FP_Tour_Step_3":"Progress bar shows take-off and landing times","FP_Tour_Step_6":"View all flights in Aviator mode","FP_Last_Seen_At":"Last seen at %1","FP_Status_Updates":"Status Updates","FP_First_Seen_At":"First seen at %1","FP_Took_Off_From":"took off from","FP_Takes_Off_From":"takes off from","FP_Landed_At":"landed at","FP_Landing_At":"landing at","FP_Not_Your_Flight":"Not your flight?","FP_Activity_Log":"Activity Log","FP_Upcoming_Flights":"Upcoming flights","FP_Date":"Date","FP_Departure":"Departure","FP_Arrival":"Arrival","FP_Aircraft":"Aircraft","FP_Duration":"Duration","FP_Enroute_Flight":"En Route flight","FP_Past_Flights":"Past flights","FP_View_More_Flight_History":"View more flight history","FP_Report_Inaccuracies":"Report inaccuracies on this page","FP_Aircraft_Type":"Aircraft Type","FP_Photos":"Photos","FP_View_All_Photos":"view all photos","FP_Details":"Details","FP_Flight_Details":"Flight Details","FP_Flight_Times":"Flight Times","FP_Takeoff":"Takeoff","FP_Landing":"Landing","FP_Actual":"Actual","FP_Scheduled":"Scheduled","FP_Elapsed":"Elapsed","FP_Remaining":"Remaining","FP_Total_Flight_Time":"Total Flight Time","FP_Track_Inbound_Plane":"Track inbound plane","FP_Departure_Times":"Departure Times","FP_Gate_Departures":"Gate Departure","FP_Taxiing":"Taxiing","FP_Estimated":"Estimated","FP_Average_Delay":"Average Delay","FP_Arrival_Times":"Arrival Times","FP_Gate_Arrival":"Gate Arrival","FP_Airline":"Airline","FP_Average_Fare":"Average Fare","FP_Cabin":"Cabin","FP_Additional_Links":"Additional Links","FP_Flight_Data":"Flight data","FP_Filed":"Filed","FP_Direct":"Direct","FP_Fuel_Burn":"Fuel Burn","FP_Route":"Route","FP_Decode":"decode","FP_Tail_Number":"Tail Number","FP_Registration":"Registration","FP_Remarks":"Remarks","FP_Edit":"edit","FP_Message_Sent_Successfully":"Message sent successfully.","FP_Seconds":"seconds","FP_Result_Unknown":"Result unknown","FP_Just_Landed":"Just landed","FP_Cancelled":"Cancelled","FP_Taxiing_Take_Off":"Taxiing for takeoff","FP_Left_Gate":"Left gate","FP_Left_Terminal":"Left terminal","FP_Upload_Photo":"upload photo","FP_A_Year":"a year","FP_Duration_Minutes":"%1 minutes","FP_Upgrade_To_See_Tail":"Upgrade account to see tail number","FP_AboutYearAgo":"about a year","FP_Duration_Hour":"%1 hour","FP_Just_Arrived":"Just arrived","FP_20m_40m":"20-40 minutes","FP_40m_1hr":"40 minutes - 1 hour","FP_MoreThanHour":"More than 1 hour","FP_10m_20m":"10-20 minutes","FP_10m":"Less than 10 minutes","FP_Duration_Hours":"%1 hours","FP_LearnMore":"learn more","FP_EstimatedArrivalTime":"estimated arrival time","FP_Duration_Hours_Minutes":"%1 hours %2 minutes","FP_A_Week":"a week","FP_AboutWeekAgo":"about a week","FP_Duration_Hour_Minute":"1 ho ...
#   </script>
#   <script crossorigin="anonymous" src="http://e0.flightcdn.com/include/bff967a4f-flightaware.js" type="text/javascript">
#   </script>
#   <script src="http://e0.flightcdn.com/ajax/ignoreall/airlines_js.rvt?locale=en_US&amp;country=US&amp;1" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var isIE10 = false;
# 			/*@cc_on
# 			if (/^10/.test(@_jscript_version)) {
# 				isIE10 = true;
# 			}
# 			@*/
#   </script>
#   <!--[if lt IE 7 ]><script type="text/javascript">var isIE6 = true;</script><![endif]-->
#   <!--[if IE 7 ]><script type="text/javascript">var isIE7 = true;</script><![endif]-->
#   <!--[if IE 8 ]><script type="text/javascript">var isIE8 = true;</script><![endif]-->
#   <!--[if IE 9 ]><script type="text/javascript">var isIE9 = true;</script><![endif]-->
#   <!-- done emit -->
#   <meta content="American Airlines (AA)  #321 Flight Tracker AAL321" name="keywords"/>
#   <meta content="American Airlines (AA)  #321 Flight Tracker (AAL321)" name="description"/>
#   <meta content="American Airlines (AA)  #321 ✈ 23-Aug-2017  ✈ KLGA - KORD" name="title"/>
#   <meta content="American Airlines (AA)  #321 ✈ 23-Aug-2017  ✈ KLGA - KORD ✈ FlightAware" property="og:title"/>
#   <meta content="FlightAware" property="og:site_name"/>
#   <meta content="http://flightaware.com/live/flight/AAL321/history/20170824/0130Z/KLGA/KORD" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <script type="text/javascript">
#    var nTime = 360000;
# 		var timePrev = Date.now();
# 		var timeoutquant;
# 		$(document).ready(function() {
# 			restarttimeouthandler();
#
# 			var activityHandler = function(delay) {
# 				if (delay === undefined) {
# 					delay = 60000;
# 				}
# 				/* Check if we're [delay] seconds from refreshing, if so
# 				   delay the page refresh by [delay] seconds. This prevents
# 				   the page from refreshing while someone is interacting
# 				   with the page. */
# 				var timeNow = Date.now();
# 				var timeDiff = timeNow - window.timePrev;
# 				if (nTime - timeDiff < delay) {
# 					window.nTime = delay;
# 					restarttimeouthandler();
# 					window.timePrev = timeNow;
# 				}
# 			}
#
# 			$(document).keydown(activityHandler);
# 			$(document).mousedown(activityHandler);
# 		});
#   </script>
#  </head>
#  <!--[if lt IE 7 ]><body class="ie6 ie67"><![endif]-->
#  <!--[if IE 7 ]><body class="ie7 ie67"><![endif]-->
#  <!--[if IE 8 ]><body class="ie8 ie89"><![endif]-->
#  <!--[if IE 9 ]><body class="ie9 ie89"><![endif]-->
#  <!--[if (gt IE 9)|!(IE)]><!-->
#  <body>
#   <!--<![endif]-->
#   <div id="iecountdown" style="display: none;">
#    <table class="fullWidth" style="background: url(http://e1.flightcdn.com/images/ie_warning.png) 0 top repeat-x;">
#     <tbody>
#      <tr align="justify">
#       <td align="center">
#        <strong>
#         Your browser is unsupported.
#        </strong>
#        <a href="https://www.google.com/chrome/browser/desktop/" id="ie6txt" style="font-weight: bold;" target="_blank">
#         upgrade your browser
#        </a>
#       </td>
#      </tr>
#     </tbody>
#    </table>
#   </div>
#   <nav aria-label="Main navigation" class="navBarMobile" id="mobileNavBar" role="navigation">
#    <ul class="topMenuList">
#     <li class="sp_menu_item">
#      <a href="/account/manage">
#       <i class="fa fa-plane">
#       </i>
#       Join FlightAware
#      </a>
#      <a class="topMenuWhyJoin" href="/about/account_types.rvt">
#       (Why Join?)
#      </a>
#     </li>
#     <li class="sp_menu_item">
#      <a class="loginLink" href="/account/login">
#       <i class="fa fa-sign-in">
#       </i>
#       Login
#      </a>
#     </li>
#     <li class="noHover " id="LocaleTopBoxItem">
#      <div id="LocaleTopBox">
#       <form action="http://flightaware.com/account/locale_switch.rvt" method="get" style="display: inline;">
#        <select class="localePicker" name="locale" onchange="this.form.submit();">
#         <option value="ar_SA">
#          العربية
#         </option>
#         <option value="cs_CZ">
#          Čeština
#         </option>
#         <option value="de_DE">
#          Deutsch
#         </option>
#         <option value="en_AU">
#          English (Australia)
#         </option>
#         <option value="en_CA">
#          English (Canada)
#         </option>
#         <option value="en_GB">
#          English (UK)
#         </option>
#         <option selected="selected" value="en_US">
#          English (USA)
#         </option>
#         <option value="es_ES">
#          Español (España)
#         </option>
#         <option value="es_MX">
#          Español
#         </option>
#         <option value="fi_FI">
#          Suomi
#         </option>
#         <option value="fr_CA">
#          Français (Canada)
#         </option>
#         <option value="fr_FR">
#          Français (France)
#         </option>
#         <option value="he_IL">
#          עִבְרִית
#         </option>
#         <option value="hi_IN">
#          हिन्दी
#         </option>
#         <option value="hr_HR">
#          Hrvatski
#         </option>
#         <option value="it_IT">
#          Italiano
#         </option>
#         <option value="ja_JP">
#          日本語
#         </option>
#         <option value="ko_KR">
#          한국어
#         </option>
#         <option value="pl_PL">
#          Polski
#         </option>
#         <option value="pt_BR">
#          Português (Brasil)
#         </option>
#         <option value="pt_PT">
#          Português (Portugal)
#         </option>
#         <option value="ru_RU">
#          Русский
#         </option>
#         <option value="tr_TR">
#          Türkçe
#         </option>
#         <option value="zh_CN">
#          中文(简体)
#         </option>
#         <option value="zh_HK">
#          中文(香港)
#         </option>
#         <option value="zh_TW">
#          中文(台灣)
#         </option>
#        </select>
#       </form>
#       <a href="http://flightaware.com/account/locale_switch.rvt?locale=en_US">
#        <img alt="US Flag" height="11" src="http://e1.flightcdn.com/images/countries/US.png" title="Switch to US FlightAware" width="16"/>
#       </a>
#      </div>
#     </li>
#    </ul>
#    <ul id="listMenuRootMobile" role="menubar">
#     <li aria-haspopup="true" class="menu_item" data-id="10" role="menuitem">
#      <a href="/live/">
#       Live Flight Tracking
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_live_trackingMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/findflight/">
#         Flight Finder
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/cancelled/">
#         Cancellations
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/airport/delays/">
#         Airport Delays
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/miserymap/">
#         MiseryMap
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/fleet/">
#         Browse by Operator
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/resources/airport/browse/">
#         Browse by Airport
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/aircrafttype/">
#         Browse by Aircraft Type
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/airport/random">
#         Random Airport
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/flight/random">
#         Random Flight
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/mobile">
#         Mobile Flight Tracker Apps
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/statistics/ifr-route/">
#         IFR Route Analyzer
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/resources/weather_maps/">
#         Weather
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/resources/emetar/">
#         E-metar
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="20" role="menuitem">
#      <a href="/commercial/">
#       Products
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_commercial_servicesMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/premium/">
#         Premium Accounts
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/advertising/">
#         Advertising
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/flightxml/">
#         FlightXML - Flight Status / Flight Tracking API
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/data/adsb/">
#         Firehose - Worldwide ADS-B Data Feed
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/data/surface_movement/">
#         Airport Surface Movement Data Feed
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/aireon/">
#         Global Space-Based ADS-B
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/data/">
#         Live Data Feeds
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/global/">
#         FlightAware Global
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/tv/">
#         FlightAware TV
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/customreports/">
#         Custom Reports
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/fbotoolbox">
#         FBO ToolBox
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="30" role="menuitem">
#      <a href="/adsb/">
#       ADS-B
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_adsbMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/stats">
#         Statistics
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/coverage">
#         Coverage Map
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/piaware/build">
#         Build a PiAware ADS-B Receiver
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/flightfeeder">
#         FlightFeeder ADS-B Receiver
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/faq">
#         FAQs
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/aireon/">
#         Global Space-Based ADS-B
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="40" role="menuitem">
#      <a href="/photos/">
#       Photos
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_photosMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/">
#         Popular Photos
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/browse/newest">
#         Newest Photos
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/ranked/cume">
#         Highest Ranked
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/staffpicks/cume">
#         Staff Picks
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/recentcomments.rvt?page=1">
#         Recent Comments
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="50" role="menuitem">
#      <a href="/squawks/">
#       Squawks
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_squawksMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/squawks/browse/general/recently/popular">
#         Current Squawks
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/squawks/browse/general/24_hours/new">
#         New Squawks
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/squawks/">
#         Popular Squawks
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="60" role="menuitem">
#      <a href="https://discussions.flightaware.com">
#       Discussions
#      </a>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="80" role="menuitem">
#      <a href="/about/">
#       About
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_about_flightawareMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/">
#         Overview
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/executives/">
#         Executive Profiles
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/history.rvt">
#         History
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/account_types.rvt">
#         Account Types
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/faq">
#         FAQs
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/merchandise/">
#         Company Store
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/careers/">
#         Careers
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/news/">
#         Newsroom
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="90" role="menuitem">
#      <a href="/about/contact/">
#       Contact
#      </a>
#     </li>
#     <li class="socialShare">
#      <div class="socialContainer">
#       <a class="facebook ss-icon" href="https://www.facebook.com/FlightAware">
#        
#       </a>
#       <ul class="social_submenu">
#        <li class="social_submenu_item">
#         <a class="share-button facebook-button" href="https://facebook.com/sharer.php?u=http://flightaware.com/live/flight/AAL321/history/20170824/0130Z/KLGA/KORD" target="_blank">
#          <i class="fa fa-facebook-official">
#          </i>
#          <span class="share-text">
#           Like
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="socialContainer">
#       <a class="twitter ss-icon" href="https://twitter.com/flightaware">
#        
#       </a>
#       <ul class="social_submenu">
#        <li class="social_submenu_item">
#         <a class="share-button tweet-button" href="https://twitter.com/intent/tweet?url=http://flightaware.com/live/flight/AAL321/history/20170824/0130Z/KLGA/KORD&amp;via=FlightAware" target="_blank">
#          <i class="fa fa-twitter">
#          </i>
#          <span class="share-text">
#           Tweet
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </li>
#    </ul>
#   </nav>
#   <div id="slideOutPanel">
#    <header id="topWrapper" role="banner">
#     <div class="topMenuBarWrapper">
#      <nav class="topMenuBar">
#       <ul class="topMenuList">
#        <li class="sp_menu_item">
#         <a href="/account/manage">
#          <i class="fa fa-plane">
#          </i>
#          Join FlightAware
#         </a>
#         <a class="topMenuWhyJoin" href="/about/account_types.rvt">
#          (Why Join?)
#         </a>
#        </li>
#        <li class="sp_menu_item">
#         <a class="loginLink" href="/account/login">
#          <i class="fa fa-sign-in">
#          </i>
#          Login
#         </a>
#        </li>
#        <li class="noHover " id="LocaleTopBoxItem">
#         <div id="LocaleTopBox">
#          <form action="http://flightaware.com/account/locale_switch.rvt" method="get" style="display: inline;">
#           <select class="localePicker" name="locale" onchange="this.form.submit();">
#            <option value="ar_SA">
#             العربية
#            </option>
#            <option value="cs_CZ">
#             Čeština
#            </option>
#            <option value="de_DE">
#             Deutsch
#            </option>
#            <option value="en_AU">
#             English (Australia)
#            </option>
#            <option value="en_CA">
#             English (Canada)
#            </option>
#            <option value="en_GB">
#             English (UK)
#            </option>
#            <option selected="selected" value="en_US">
#             English (USA)
#            </option>
#            <option value="es_ES">
#             Español (España)
#            </option>
#            <option value="es_MX">
#             Español
#            </option>
#            <option value="fi_FI">
#             Suomi
#            </option>
#            <option value="fr_CA">
#             Français (Canada)
#            </option>
#            <option value="fr_FR">
#             Français (France)
#            </option>
#            <option value="he_IL">
#             עִבְרִית
#            </option>
#            <option value="hi_IN">
#             हिन्दी
#            </option>
#            <option value="hr_HR">
#             Hrvatski
#            </option>
#            <option value="it_IT">
#             Italiano
#            </option>
#            <option value="ja_JP">
#             日本語
#            </option>
#            <option value="ko_KR">
#             한국어
#            </option>
#            <option value="pl_PL">
#             Polski
#            </option>
#            <option value="pt_BR">
#             Português (Brasil)
#            </option>
#            <option value="pt_PT">
#             Português (Portugal)
#            </option>
#            <option value="ru_RU">
#             Русский
#            </option>
#            <option value="tr_TR">
#             Türkçe
#            </option>
#            <option value="zh_CN">
#             中文(简体)
#            </option>
#            <option value="zh_HK">
#             中文(香港)
#            </option>
#            <option value="zh_TW">
#             中文(台灣)
#            </option>
#           </select>
#          </form>
#          <a href="http://flightaware.com/account/locale_switch.rvt?locale=en_US">
#           <img alt="US Flag" height="11" src="http://e1.flightcdn.com/images/countries/US.png" title="Switch to US FlightAware" width="16"/>
#          </a>
#         </div>
#        </li>
#        <li class="fadate-clock noHover" id="headerClock">
#         <span title="EDT">
#          11:24AM EDT
#         </span>
#        </li>
#       </ul>
#      </nav>
#     </div>
#     <div id="topContent">
#      <div class="menuIcon">
#       <i class="fa fa-bars">
#       </i>
#      </div>
#      <div class="logoLeft float_left">
#       <a href="/">
#        <img alt="FlightAware" class="faLogo " src="http://e1.flightcdn.com/images/fa_logo_white.png"/>
#       </a>
#      </div>
#      <div class="headerTrack" id="headerSearchForm">
#       <div class="flightSearchForm">
#        <div class="searchToggle text_align_right">
#         <div class="search_in">
#          <span class="search_in_content">
#           All
#          </span>
#          <select class="trackSelect">
#           <option value="omniSearch">
#            All
#           </option>
#           <option value="routeSearch">
#            Route
#           </option>
#           <option value="airlineSearch">
#            Airline flight
#           </option>
#           <option value="privateSearch">
#            Private flight (tail #)
#           </option>
#           <option value="airportSearch">
#            Airport
#           </option>
#          </select>
#         </div>
#        </div>
#        <div class="searchOption active" data-fa-search-type="omniSearch" id="omniSearch">
#         <div class="fa_omnisearch_container">
#          <form action="//flightaware.com/ajax/ignoreall/omnisearch/disambiguation.rvt" id="omnisearch_form" method="get">
#           <input name="searchterm" type="hidden" value=""/>
#           <input name="token" type="hidden" value=""/>
#           <input data-alias="flightaware.com" data-ambiguous="More results for %1 ..." data-placeholder="   Search for flight, tail, airport, or city" data-recent="Recent Searches" data-searching="Searching..." data-server="e1.flightcdn.com" data-startsearch="Please begin searching to receive suggestions" data-version="43" id="omni_headerSearchForm" tabindex="1" type="hidden"/>
#           <div class="omnisearch_loading" style="display:none;">
#            <i class="fa fa-spinner fa-pulse">
#            </i>
#           </div>
#          </form>
#         </div>
#        </div>
#        <div class="searchOption routeSearch hide text_align_left" data-fa-search-type="routeSearch">
#         <form action="/live/findflight">
#          <div class="trackInputContainer">
#           <div class="trackInput">
#            <input aria-label="Origin" class="trackRouteOrigin" name="origin" placeholder="Origin (e.g. KJFK)" tabindex="1" title="Origin (e.g. KJFK)" type="text"/>
#           </div>
#          </div>
#          <div class="route_swap">
#           <div class="header_swap">
#            <img alt="Swap" src="http://e1.flightcdn.com/images/home_main/swap_icon.png"/>
#           </div>
#          </div>
#          <div class="trackInputContainer">
#           <div class="trackInput">
#            <input aria-label="Destination " class="trackRouteDestination" name="destination" placeholder="Destination  (e.g. KLAX)" tabindex="2" title="Destination  (e.g. KLAX)" type="text"/>
#           </div>
#          </div>
#          <input hidefocus="true" style="display: none;" type="submit"/>
#         </form>
#        </div>
#        <div class="searchOption multiple hide text_align_left" data-fa-search-type="airlineSearch">
#         <form action="/live/form.rvt" class="airlineSearch">
#          <div class="trackInputContainer airlineName ">
#           <div class="trackInput">
#            <input aria-label="Airline (e.g. United)" class="trackAirlineName" id="airline_name" name="q" placeholder="Airline (e.g. United)" tabindex="2" title="Airline (e.g. United)" type="text" value="American Airlines  - AAL"/>
#           </div>
#          </div>
#          <div class="trackInputContainer flightNumber ">
#           <div class="trackInput">
#            <input aria-label="Flight # (e.g. 450)" class="trackAirlineNumber" id="ident_suffix" name="ident_suffix" placeholder="Flight # (e.g. 450)" tabindex="3" title="Flight # (e.g. 450)" type="text" value="321"/>
#           </div>
#          </div>
#          <input id="ident_prefix" name="ident_prefix" type="hidden"/>
#          <input hidefocus="true" style="display: none;" type="submit"/>
#          <span class="fa fa-times-circle-o" id="airlineSearchCancel">
#          </span>
#         </form>
#        </div>
#        <form action="/live/form.rvt" class="searchOption hide text_align_left" data-fa-search-type="privateSearch" id="privateSearch">
#         <div class="trackInput">
#          <input aria-label="Flight/Tail# (e.g. N123AB)" class="trackTail" name="ident" placeholder="Flight/Tail# (e.g. N123AB)" tabindex="4" title="Flight/Tail# (e.g. N123AB)" type="text" value=""/>
#         </div>
#        </form>
#        <form action="/live/form.rvt" class="searchOption multiple hide text_align_left" data-fa-search-type="airportSearch" id="airportSearch">
#         <div class="trackInput">
#          <input aria-label="Airport Code (e.g. KJFK)" class="trackAirportCode" id="airport" name="airport" placeholder="Airport Code (e.g. KJFK)" tabindex="5" title="Airport Code (e.g. KJFK)" type="text" value=""/>
#         </div>
#         <div class="trackInput">
#          <input aria-label="Airport City (e.g. New York)" class="trackAirportCity" id="airport_name_or_city" name="airport_name_or_city" placeholder="Airport City (e.g. New York)" tabindex="6" title="Airport City (e.g. New York)" type="text"/>
#         </div>
#         <input hidefocus="true" style="display: none;" type="submit"/>
#        </form>
#        <div class="trackSubmit">
#         <button class="orange_button" tabindex="7" type="submit">
#          Track
#         </button>
#        </div>
#       </div>
#      </div>
#      <nav aria-label="Main navigation" class="navBar" role="navigation">
#       <ul id="listMenuRoot" role="menubar">
#        <li aria-haspopup="true" class="menu_item" data-id="10" role="menuitem">
#         <a href="/live/">
#          Live Flight Tracking
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_live_tracking" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/findflight/">
#            Flight Finder
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/cancelled/">
#            Cancellations
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/airport/delays/">
#            Airport Delays
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/miserymap/">
#            MiseryMap
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/fleet/">
#            Browse by Operator
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/resources/airport/browse/">
#            Browse by Airport
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/aircrafttype/">
#            Browse by Aircraft Type
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/airport/random">
#            Random Airport
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/flight/random">
#            Random Flight
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/mobile">
#            Mobile Flight Tracker Apps
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/statistics/ifr-route/">
#            IFR Route Analyzer
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/resources/weather_maps/">
#            Weather
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/resources/emetar/">
#            E-metar
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="20" role="menuitem">
#         <a href="/commercial/">
#          Products
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_commercial_services" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/premium/">
#            Premium Accounts
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/advertising/">
#            Advertising
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/flightxml/">
#            FlightXML - Flight Status / Flight Tracking API
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/data/adsb/">
#            Firehose - Worldwide ADS-B Data Feed
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/data/surface_movement/">
#            Airport Surface Movement Data Feed
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/aireon/">
#            Global Space-Based ADS-B
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/data/">
#            Live Data Feeds
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/global/">
#            FlightAware Global
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/tv/">
#            FlightAware TV
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/customreports/">
#            Custom Reports
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/fbotoolbox">
#            FBO ToolBox
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="30" role="menuitem">
#         <a href="/adsb/">
#          ADS-B
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_adsb" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/stats">
#            Statistics
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/coverage">
#            Coverage Map
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/piaware/build">
#            Build a PiAware ADS-B Receiver
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/flightfeeder">
#            FlightFeeder ADS-B Receiver
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/faq">
#            FAQs
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/aireon/">
#            Global Space-Based ADS-B
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="40" role="menuitem">
#         <a href="/photos/">
#          Photos
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_photos" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/">
#            Popular Photos
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/browse/newest">
#            Newest Photos
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/ranked/cume">
#            Highest Ranked
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/staffpicks/cume">
#            Staff Picks
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/recentcomments.rvt?page=1">
#            Recent Comments
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="50" role="menuitem">
#         <a href="/squawks/">
#          Squawks
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_squawks" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/squawks/browse/general/recently/popular">
#            Current Squawks
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/squawks/browse/general/24_hours/new">
#            New Squawks
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/squawks/">
#            Popular Squawks
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="60" role="menuitem">
#         <a href="https://discussions.flightaware.com">
#          Discussions
#         </a>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="80" role="menuitem">
#         <a href="/about/">
#          About
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_about_flightaware" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/">
#            Overview
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/executives/">
#            Executive Profiles
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/history.rvt">
#            History
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/account_types.rvt">
#            Account Types
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/faq">
#            FAQs
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/merchandise/">
#            Company Store
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/careers/">
#            Careers
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/news/">
#            Newsroom
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="90" role="menuitem">
#         <a href="/about/contact/">
#          Contact
#         </a>
#        </li>
#        <li class="socialShare">
#         <div class="socialContainer">
#          <a class="facebook ss-icon" href="https://www.facebook.com/FlightAware">
#           
#          </a>
#          <ul class="social_submenu">
#           <li class="social_submenu_item">
#            <a class="share-button facebook-button" href="https://facebook.com/sharer.php?u=http://flightaware.com/live/flight/AAL321/history/20170824/0130Z/KLGA/KORD" target="_blank">
#             <i class="fa fa-facebook-official">
#             </i>
#             <span class="share-text">
#              Like
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="socialContainer">
#          <a class="twitter ss-icon" href="https://twitter.com/flightaware">
#           
#          </a>
#          <ul class="social_submenu">
#           <li class="social_submenu_item">
#            <a class="share-button tweet-button" href="https://twitter.com/intent/tweet?url=http://flightaware.com/live/flight/AAL321/history/20170824/0130Z/KLGA/KORD&amp;via=FlightAware" target="_blank">
#             <i class="fa fa-twitter">
#             </i>
#             <span class="share-text">
#              Tweet
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </header>
#    <div class="pageContainer">
#     <script type="text/javascript">
#      $(function(){new FlightPage();});
#     </script>
#     <div class="flightPageAd flightPageNewAdUnit" data-set="flightPageAds">
#     </div>
#     <div class="flightPageContainer">
#      <div class="flightPageBlockedData" data-template="live/flight/blocked">
#      </div>
#      <div class="flightPageUnknownData" data-template="live/flight/unknown">
#      </div>
#      <div class="flightPageSummaryMap">
#       <div data-template="live/flight/summary">
#       </div>
#       <div data-template="live/flight/summaryLinks">
#       </div>
#       <div data-template="live/flight/airportDelays">
#       </div>
#       <div data-template="live/flight/adhoc">
#       </div>
#       <div class="flightPageMapContainer" id="flightPageTourStepMap">
#        <div id="flightPageInteractiveMap" style="width:100%; height:600px;">
#        </div>
#        <div class="flightPageStaticMapContainer" data-server="flightxml.flightaware.com">
#         <div class="flightPageStaticMap" data-disable-refresh="true" data-template="live/flight/staticMap">
#         </div>
#         <div class="flightPageNotificationContainer" data-template="live/flight/notification">
#         </div>
#        </div>
#        <div id="flightPageReplayControl">
#        </div>
#       </div>
#       <div class="flightPageSummaryMapDetails">
#        <div data-template="live/flight/airline">
#        </div>
#        <div data-template="live/flight/data">
#        </div>
#       </div>
#       <div class="flightPageActivityLogTop" data-set="flightPageRemarksActivityLog">
#        <div class="remarksAndActivityLog" data-template="live/flight/positionOnly" id="flightPagePositionOnly">
#        </div>
#        <div class="flightPageActivityLog remarksAndActivityLog" data-template="live/flight/log" id="flightPageActivityLog">
#        </div>
#       </div>
#      </div>
#      <div class="flightPageDetails">
#       <div class="flightPageCondensedSummary" data-template="live/flight/summary">
#       </div>
#       <div class="flightPageSponsorshipAd viewableAdHome" data-set="flightPageAds">
#        <div class="flightPageAdUnit">
#         <script>
#          var googletag = googletag || {};
# 			googletag.cmd = googletag.cmd || [];
# 			(function() {
#
# 				var gads = document.createElement('script');
# 				gads.async = true;
# 				gads.type = 'text/javascript';
# 				var useSSL = 'https:' == document.location.protocol;
# 				gads.src = (useSSL ? 'https:' : 'http:') +
# 				'//www.googletagservices.com/tag/js/gpt.js';
# 				var node = document.getElementsByTagName('script')[0];
# 				node.parentNode.insertBefore(gads, node);
#
# 			})();
# 			if (typeof googletag.enableSingleRequest === 'function') {
# 				googletag.cmd.push(function() { googletag.enableSingleRequest(); });
# 			}
#
# 				var displayGoogleAd = function(id) { googletag.display(id); }
#         </script>
#         <script>
#          googletag.cmd.push(function() {
# 					var mapping = googletag.sizeMapping().addSize([0,0], [[320,50]]).addSize([768,0], [[300,250]]).build();
# 					googletag.defineSlot('/6254/flight.main/live/flight/atf', [[300,250]], 'FA_ads_578417').defineSizeMapping(mapping).addService(googletag.pubads()).setTargeting('aircraft_make', 'Boeing').setTargeting('aircraft_model', '737-800').setTargeting('aircraft_type', 'B738').setTargeting('dcove', 'd').setTargeting('destination', 'KORD').setTargeting('destination_IATA', 'ORD').setTargeting('destination_state', 'IL').setTargeting('engine_category', 'turbine').setTargeting('engine_type', 'twin-jet').setTargeting('filed_ete', '1h2h').setTargeting('flightstatus', 'arrived').setTargeting('ident', 'AAL321').setTargeting('lang', 'en').setTargeting('lifeguard', '0').setTargeting('locale', 'en_US').setTargeting('origin', 'KLGA').setTargeting('origin_IATA', 'LGA').setTargeting('origin_state', 'NY').setTargeting('physclass', 'J').setTargeting('prefix', 'AAL').setTargeting('type', 'airline').setTargeting('unitName', 'flight').setTargeting('userGen', 'f').setTargeting('userclass', '');
# 					googletag.pubads().setCentering(true);
# 					googletag.enableServices();
# 				});
#         </script>
#         <div class="fa-google-ad" id="FA_ads_578417" style="min-height:250px;">
#         </div>
#        </div>
#       </div>
#       <div class="flightPageNotificationContainer" data-template="live/flight/notification">
#       </div>
#       <div data-template="live/flight/airportDelays">
#       </div>
#       <div data-template="live/flight/details">
#       </div>
#       <div data-template="live/flight/airline">
#       </div>
#       <div data-template="live/flight/data">
#       </div>
#       <div data-disable-refresh="true" data-template="live/flight/thumbnailCarousel">
#       </div>
#       <div class="flightPageYieldMoAd" data-set="flightPageAdsBottom">
#       </div>
#       <div class="flightPageRemarks remarksAndActivityLog" data-template="live/flight/remarks">
#       </div>
#       <div class="flightPageReportInaccuraciesRight" data-set="flightPageReportInaccuracies">
#       </div>
#       <div class="flightPageSponsorshipAd">
#       </div>
#      </div>
#      <div class="flightPageActivityLogBottom" data-set="flightPageRemarksActivityLog">
#      </div>
#      <div class="flightPageReportInaccuraciesBottom" data-set="flightPageReportInaccuracies">
#       <div class="flightPageReportInaccuracies" data-disable-refresh="true" data-template="live/flight/reportInaccuracies">
#       </div>
#      </div>
#      <div data-disable-refresh="true" data-template="live/flight/modal/notifications">
#      </div>
#      <div data-disable-refresh="true" data-template="live/flight/modal/settings">
#      </div>
#      <div data-disable-refresh="true" data-template="live/flight/modal/remark">
#      </div>
#     </div>
#     <div class="flightPageAdBottom flightPageNewAdUnit" data-set="flightPageAdsBottom">
# ...
#   </script>
#   <script data-tpl="live/flight/reportInaccuracies" type="text/javascript">
#    !function(){var a=Handlebars.template,e=Handlebars.templates=Handlebars.templates||{};e.reportInaccuracies=a({1:function(a,e,t,i,l){return'<p>Please provide an email address where we can contact you for more information:</p>\n<input type="email" name="email" id="flightPageReportEmail" class="flightPageReportEmail">\n'},compiler:[7,">= 4.0.0"],main:function(a,e,t,i,l){var n,r=null!=e?e:{},o=t.helperMissing,s=a.escapeExpression;return'<!-- Report inaccuracies -->\n\n<h3 id="flightPageReportPanel" class="flightPageDataTableHeading" data-collapsible="true"><i class="fa fa-plus-square" aria-hidden="true"></i> <span>'+s((t.mc||e&&e.mc||o).call(r,"FP_Report_Inaccuracies","Report inaccuracies on this page",{name:"mc",hash:{},data:l}))+'</span></h3>\n\n\n<div class="flightPageReportInaccuraciesForm flightPageDataTable" id="flightPageReportInaccuraciesForm">\n<form id="reportInaccuracies" method="post" action="'+s(a.lambda(null!=(n=null!=e?e.links:e)?n.reportInaccuracies:n,e))+'" enctype="multipart/form-data">\n<input type="hidden" name="json_report" id="json_report" value="">\n<input type="radio" name="errorRadio" id="times" value="times">\n<input type="radio" name="errorRadio" id="airports" value="airports">\n<input type="radio" name="errorRadio" id="aircraft_type" value="aircraft_type">\n<input type="radio" name="errorRadio" id="path" value="path">\n<input type="radio" name="errorRadio" id="not_cancelled" value="not_cancelled">\n<input type="radio" name="errorRadio" id="cancelled" value="cancelled">\n<input type="radio" name="errorRadio" id="other" value="other">\n<h3 class="flightPageDataTableHeading">Please Identify The Issue</h3>\n<div class="flightPageDataTable">\n<div class="flightPageDataRow">\n<label for="times" class="flightPageReportType">Inaccurate arrival/departure time</label>\n</div>\n<div class="flightPageDataRow">\n<label for="airports" class="flightPageReportType">Inaccurate origin/destination airport</label>\n</div>\n<div class="flightPageDataRow">\n<label for="aircraft_type" class="flightPageReportType">Inaccurate aircraft type</label>\n</div>\n<div class="flightPageDataRow">\n<label for="path" class="flightPageReportType">Inaccurate depicted flight path on map</label>\n</div>\n<div class="flightPageDataRow">\n<label for="not_cancelled" class="flightPageReportType">Flight was shown as canceled, but actually operated</label>\n</div>\n<div class="flightPageDataRow">\n<label for="cancelled" class="flightPageReportType">Flight should have been shown as canceled</label>\n</div>\n<div class="flightPageDataRow">\n<label for="other" class="flightPageReportType">Other (please explain below)</label>\n</div>\n</div>\n<div class="flightPageReportDetails">\n<div class="flightPageReportComments">\n<p>Please provide any additional clarifying information:</p>\n<textarea class="flightPageReportTextarea" id="flightPageReportTextarea" name="clarification"></textarea>\n</div>\n<div class="flightPageReportEmailAndFile">\n'+(null!=(n=t.unless.call(r,(t.isLoggedIn||e&&e.isLoggedIn||o).call(r,{name:"isLoggedIn",hash:{},data:l}),{name:"unless",hash:{},fn:a.program(1,l,0),inverse:a.noop,data:l}))?n:"")+'<p>If possible, upload a screenshot or image demonstrating the issue: <input type="file" name="media" class="flightPageReportFile" id="flightPageReportFile"></p>\n\n\n<p class="flightPageReportButton"><a href="#" class="flightPageButton" data-action="reportInaccuracies"><span>Submit Report</span></a></p>\n</div>\n</div>\n</form>\n</div>'},useData:!0})}();
#   </script>
#   <script data-tpl="live/flight/positionOnly" type="text/javascript">
#    !function(){var e=Handlebars.template,n=Handlebars.templates=Handlebars.templates||{};n.positionOnly=e({1:function(e,n,a,i,s){var l,t=null!=n?n:{};return null!=(l=a.if.call(t,(a.suggestAdhoc||n&&n.suggestAdhoc||a.helperMissing).call(t,{name:"suggestAdhoc",hash:{},data:s}),{name:"if",hash:{},fn:e.program(2,s,0),inverse:e.noop,data:s}))?l:""},2:function(e,n,a,i,s){var l,t=null!=n?n:{},r=a.helperMissing;return'<div id="suggestAdhocNotice" class="flightPageAdhocNotice">\n<p><strong>'+e.escapeExpression((a.mc||n&&n.mc||r).call(t,"FP_Hidden_Flights_Summary","There are flights hidden from view because they were not matched with a flight plan.",{name:"mc",hash:{},data:s}))+"</strong></p>\n"+(null!=(l=a.if.call(t,(a.isActiveUser||n&&n.isActiveUser||r).call(t,{name:"isActiveUser",hash:{},data:s}),{name:"if",hash:{},fn:e.program(3,s,0),inverse:e.program(5,s,0),data:s}))?l:"")+"</div>\n"},3:function(e,n,a,i,s){return'<a id="showAdhoc" href="javascript:void(0)">'+e.escapeExpression((a.mc||n&&n.mc||a.helperMissing).call(null!=n?n:{},"FP_Hidden_Flights_View","View all hidden position-only flights",{name:"mc",hash:{},data:s}))+"</a>\n"},5:function(e,n,a,i,s){var l,t=null!=n?n:{};return null!=(l=a.if.call(t,(a.isLoggedIn||n&&n.isLoggedIn||a.helperMissing).call(t,{name:"isLoggedIn",hash:{},data:s}),{name:"if",hash:{},fn:e.program(6,s,0),inverse:e.program(8,s,0),data:s}))?l:""},6:function(e,n,a,i,s){return"<p><strong>"+e.escapeExpression((a.mc||n&&n.mc||a.helperMissing).call(null!=n?n:{},"FP_Hidden_Flights_Act_Account","%1Activate%2 your account to show position-only flights.",'<a href="/account/act">',"</a>",{name:"mc",hash:{},data:s}))+"</strong></p>\n"},8:function(e,n,a,i,s){var l,t=null!=n?n:{},r=a.helperMissing;return'<a id="redirectAdhoc" href="'+(null!=(l=(a.refererLink||n&&n.refererLink||r).call(t,"/account/login",{name:"refererLink",hash:{},data:s}))?l:"")+'">'+e.escapeExpression((a.mc||n&&n.mc||r).call(t,"FP_Hidden_Flights_Login","Login or create an account to view hidden flights",{name:"mc",hash:{},data:s}))+"</a>\n"},compiler:[7,">= 4.0.0"],main:function(e,n,a,i,s){var l;return"<!-- Notification to enable position-only flights -->\n"+(null!=(l=a.unless.call(null!=n?n:{},null!=n?n.adhoc:n,{name:"unless",hash:{},fn:e.program(1,s,0),inverse:e.noop,data:s}))?l:"")},useData:!0})}();
#   </script>
#   <script data-tpl="live/flight/notificationButton_partial" type="text/javascript">
#    !function(){var a=Handlebars.template;Handlebars.templates=Handlebars.templates||{};Handlebars.partials.notificationButton_partial=a({1:function(a,n,t,i,l){var o,e=null!=n?n:{},s=t.helperMissing,c="function",r=a.escapeExpression;return'<a href="'+r((o=null!=(o=t.notificationUrl||(null!=n?n.notificationUrl:n))?o:s,typeof o===c?o.call(e,{name:"notificationUrl",hash:{},data:l}):o))+'" class="'+r((o=null!=(o=t.notificationClasses||(null!=n?n.notificationClasses:n))?o:s,typeof o===c?o.call(e,{name:"notificationClasses",hash:{},data:l}):o))+'">'+r((o=null!=(o=t.notificationContent||(null!=n?n.notificationContent:n))?o:s,typeof o===c?o.call(e,{name:"notificationContent",hash:{},data:l}):o))+"</a>\n"},3:function(a,n,t,i,l){var o,e=null!=n?n:{};return null!=(o=t.if.call(e,(t.hasArrived||n&&n.hasArrived||t.helperMissing).call(e,{name:"hasArrived",hash:{},data:l}),{name:"if",hash:{},fn:a.program(4,l,0),inverse:a.program(6,l,0),data:l}))?o:""},4:function(a,n,t,i,l){var o,e=null!=n?n:{},s=t.helperMissing,c="function",r=a.escapeExpression;return'<a href="'+r((o=null!=(o=t.notificationUrl||(null!=n?n.notificationUrl:n))?o:s,typeof o===c?o.call(e,{name:"notificationUrl",hash:{},data:l}):o))+'" class="'+r((o=null!=(o=t.notificationClasses||(null!=n?n.notificationClasses:n))?o:s,typeof o===c?o.call(e,{name:"notificationClasses",hash:{},data:l}):o))+'" data-reveal-id="flightPageNotificationModal" title="'+r((t.mc||n&&n.mc||s).call(e,"FP_Status_Updates_Not_Available","Status updates are not available for historical flights.",{name:"mc",hash:{},data:l}))+'">'+r((o=null!=(o=t.notificationContent||(null!=n?n.notificationContent:n))?o:s,typeof o===c?o.call(e,{name:"notificationContent",hash:{},data:l}):o))+"</a>\n"},6:function(a,n,t,i,l){var o,e=null!=n?n:{},s=t.helperMissing,c="function",r=a.escapeExpression;return'<a href="'+r((o=null!=(o=t.notificationUrl||(null!=n?n.notificationUrl:n))?o:s,typeof o===c?o.call(e,{name:"notificationUrl",hash:{},data:l}):o))+'" class="'+r((o=null!=(o=t.notificationClasses||(null!=n?n.notificationClasses:n))?o:s,typeof o===c?o.call(e,{name:"notificationClasses",hash:{},data:l}):o))+'" data-reveal-id="flightPageNotificationModal">'+r((o=null!=(o=t.notificationContent||(null!=n?n.notificationContent:n))?o:s,typeof o===c?o.call(e,{name:"notificationContent",hash:{},data:l}):o))+"</a>\n"},compiler:[7,">= 4.0.0"],main:function(a,n,t,i,l){var o;return null!=(o=t.if.call(null!=n?n:{},null!=n?n.ga:n,{name:"if",hash:{},fn:a.program(1,l,0),inverse:a.program(3,l,0),data:l}))?o:""},useData:!0})}();
#   </script>
#   <script>
#    $(window).one('createMap.flightPageInteractiveMap', function(){
# 				FAMap_1_promise = FAMap.factory('flightPageInteractiveMap', function(){ return FAMap.Util.ConfigPresets.getFullConfig('flight', {"groups":["anonUsers","earthcastUsers","aviationCharts"],"FAS":false,"defaultExtent":[-13854058.502631625161,3130860.6785608194768,-8022830.4888120982796,6457400.1495316904038],"analytics":"Google","fullsizeMapUrl":"/live/flight/map/AAL321/history/20170824/0130Z/KLGA/KORD"}) });
# 			});
#   </script>
#   <script type="text/javascript">
#    $(function() {
# 			$("body").append("<iframe src='/ajax/ignoreall/hash2.rvt?k=travel,flight,flight to New York,flight from Chicago,American Airlines Inc.' style='display: none;'></iframe>");
# 		});
#   </script>
#   <script>
#    var trackpollBootstrap = {"version":"2.0","summary":false,"flights":{"AAL321-1503293144-airline-0153":{"activityLog":{"flights":[{"origin":{"TZ":":America/New_York","isValidAirportCode":true,"altIdent":null,"iata":"LGA","friendlyName":"LaGuardia","friendlyLocation":"New York, NY","coord":[-73.8726,40.7773],"icao":"KLGA","gate":null,"terminal":"B","delays":null},"destination":{"TZ":":America/Chicago","isValidAirportCode":true,"altIdent":null,"iata":"ORD","friendlyName":"Chicago O'Hare Intl","friendlyLocation":"Chicago, IL","coord":[-87.9080,41.9773],"icao":"KORD","gate":null,"terminal":"3","delays":null},"aircraftType":"B738","aircraftTypeFriendly":"Boeing 737-800 (twin-jet)","flightId":"AAL321-1506921956-airline-0104","takeoffTimes":{"scheduled":1507167000,"estimated":1507167600,"actual":null},"landingTimes":{"scheduled":1507175340,"estimated":1507175940,"actual":null},"gateDepartureTimes":{"scheduled":1507167000,"estimated":null,"actual":null},"gateArrivalTimes":{"scheduled":1507176540,"estimated":null,"actual":null},"ga":false,"cancelled":false,"resultUnknown":false,"diverted":false,"adhoc":false,"fruOverride":false,"timestamp":null,"permaLink":"/live/flight/AAL321/history/20171005/0130Z/KLGA/KORD"},{"origin":{"TZ":":America/New_York","isValidAirportCode":true,"altIdent":null,"iata":"LGA","friendlyName":"LaGuardia","friendlyLocation":"New York, NY","coord":[-73.8726,40.7773],"icao":"KLGA","gate":"D8","terminal":"B","delays":null},"destination":{"TZ":":America/Chicago","isValidAirportCode":true,"altIdent":null,"iata":"ORD","friendlyName":"Chicago O'Hare Intl","friendlyLocation":"Chicago, IL","coord":[-87.9080,41.9773],"icao":"KORD","gate":"K9","terminal":"3","delays":null},"aircraftType":"B738","aircraftTypeFriendly":"Boeing 737-800 (twin-jet)","flightId":"AAL321-1506835565-airline-0272","takeoffTimes":{"scheduled":1507080600,"estimated":1507081200,"actual":null},"landingTimes":{"scheduled":1507088940,"estimated":1507089540,"actual":null},"gateDepartureTimes":{"scheduled":1507080600,"estimated":null,"actual":null},"gateArrivalTimes":{"scheduled":1507090140,"estimated":null,"actual":null},"ga":false,"cancelled":false,"resultUnknown":false,"diverted":false,"adhoc":false,"fruOverride":false,"timestamp":null,"permaLink":"/live/flight/AAL321/history/20171004/0130Z/KLGA/KORD"},{"origin":{"TZ":":America/New_York","isValidAirportCode":true,"altIdent":null,"iata":"LGA","friendlyName":"LaGuardia","friendlyLocation":"New York, NY","coord":[-73.8726,40.7773],"icao":"KLGA","gate":"D8","terminal":"B","delays":null},"destination":{"TZ":":America/Chicago","isValidAirportCode":true,"altIdent":null,"iata":"ORD","friendlyName":"Chicago O'Hare Intl","friendlyLocation":"Chicago, IL","coord":[-87.9080,41.9773],"icao":"KORD","gate":"K9","terminal":"3","delays":null},"aircraftType":"B738","aircraftTypeFriendly":"Boeing 737-800 (twin-jet)","flightId":"AAL321-1506749163-airline-0630","takeoffTimes":{"scheduled":1506994200,"estimated":1506994440,"actual":1506994440},"landingTimes":{"scheduled":1507002600,"estimated":1507001160,"actual":1507001160},"gateDepartureTimes":{"scheduled":1506994200,"estimated":1506993540,"actual":1506993540},"gateArrivalTimes":{"scheduled":1507003740,"estimated":1507001820,"actual":1507001820},"ga":false,"cancelled":false,"resultUnknown":false,"diverted":false,"adhoc":false,"fruOverride":false,"timestamp":null,"permaLink":"/live/flight/AAL321/history/20171003/0130Z/KLGA/KORD"},{"origin":{"TZ":":America/New_York","isValidAirportCode":true,"altIdent":null,"iata":"LGA","friendlyName":"LaGuardia","friendlyLocation":"New York, NY","coord":[-73.8726,40.7773],"icao":"KLGA","gate":"D8","terminal":"B","delays":null},"destination":{"TZ":":America/Chicago","isValidAirportCode":true,"altIdent":null,"iata":"ORD","friendlyName":"Chicago O'Hare Intl","friendlyLocation":"Chicago, IL","coord":[-87.9080,41.9773],"icao":"KORD","gate":"H6","terminal":"3","delays":null},"aircraftType":"B738","aircraftTypeFriendly":"Boeing 737-800 (twin-jet)"," ...
#   </script>
#   <script crossorigin="anonymous" src="http://e1.flightcdn.com/include/6247bc739-maps/TrackPollClient.js" type="text/javascript">
#   </script>
#   <script>
#    var trackpollGlobals = {"TOKEN":"c35ca45ecbca57cd1ea443d1c65c36426ea06630de026ffd737977e4a40a26ead614b3f2ddde9907453c214a859f7965-dd1320656957446e5ca0b3670908242458922d443cbc98e747985654d10df2942af08e78c2c6462beffc2a80a6a9a1e2-d72af3542c624f9a9f0cce5febe3b0d90b30cd24","INTERVAL":65,"SINGLE_FLIGHT":true,"USERTOKEN":""};
#   </script>
#   <script type="text/javascript">
#    (function(FA) { FA.headerSearch = (function() { var flightSearchForm = new FA.Modules.UI.FlightSearchForm('headerSearchForm', { 'stateSelectorClass' : '.trackSelect' , 'dashboardView' : 'toggle' } ); flightSearchForm.init();  return flightSearchForm; })(); })(FA);
#   </script>
#   <script type="text/javascript">
#    $("#headerSearchForm .flightSearchForm").append('<div class="forgot"><a href="/live/findflight/" > FORGOT the FLIGHT  NUMBER? </a></div>');
#   </script>
#   <script crossorigin="anonymous" src="http://e1.flightcdn.com/include/9fefb032d-flightpage/model.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
print(soup_nf.prettify())
# Out:
# <!DOCTYPE html>
# <html class="responsive-full" dir="LTR" lang="en">
#  <!--
# Looking at the source?  Great!
#   FlightAware is looking for UI/UX, web, and backend developers, mathematicians and electrical engineers.
#
# Get in touch with us:
# https://flightaware.com/about/careers
#
# -->
#  <head>
#   <!-- 	Attention! You must agree with FlightAware's Terms of Use at http://flightaware.com/about/termsofuse
#   Data robots and collection agents should use http://flightaware.com/commercial/flightxml/
#             Copyright 2017 FlightAware.  All Rights Reserved. -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="@FlightAware" name="twitter:site"/>
#   <title>
#    ✈ 23-Aug-2016  ✈ KLGA - KORD ✈ FlightAware
#   </title>
#   <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/>
#   <link href="/opensearch.xml" rel="search" title="FlightAware" type="application/opensearchdescription+xml"/>
#   <link href="http://e0.flightcdn.com/images/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#   <!-- non scripts -->
#   <link href="http://e0.flightcdn.com/include/0d5859c97-flightpage/flightpage.css" rel="stylesheet" type="text/css"/>
#   <link href="http://e0.flightcdn.com/include/0d5859c97-foundation/foundation.css" rel="stylesheet" type="text/css"/>
#   <link href="http://e1.flightcdn.com/include/0d5859c97-flightaware.css" rel="stylesheet" type="text/css"/>
#   <script>
#    if(typeof window.performance === 'object' && typeof window.performance.navigation === 'object' && window.performance.navigation.type == 2) {
# 											location.reload();
# 										}
#   </script>
#   <!--[if lt IE 9]>
# <script>
# document.createElement('header');
# document.createElement('nav');
# document.createElement('section');
# document.createElement('article');
# document.createElement('aside');
# document.createElement('footer');
# document.createElement('hgroup');
# </script>
# <![endif]-->
#   <!-- scripts -->
#   <script type="text/javascript">
#    user = {"username":"","TZ":":America/New_York","accounttype":"0","email":"","id":"","locale":"en_US","lang":"en","name":" ","active":"","arincUser":false,"fboUser":false,"distance_units":"sm","airportCode":"","altitudeDisplay":"feet","speedDisplay":"miles","fuelBurnDisplay":"gallons","flightpageLayout":"0","comma":",","decimal":".","adhocEnabled":false};
#   </script>
#   <script type="text/javascript">
#    var FAIntegrationConfig = {"enabled":false,"idents":[]};
#   </script>
#   <script type="text/javascript">
#    var airportNamesUrl = 'http://e0.flightcdn.com/ajax/ignoreall/airport_names_yajl.rvt', airportValidateUrl = 'http://e1.flightcdn.com/ajax/validate_airport.rvt';
#   </script>
#   <script>
#    var rosettaBootstrap = {"FP_Link_All_Flights":"all flights","FP_Tour_The_Page":"Tour the page","FP_Header_Live_Flight_Tracker":"Live Flight Tracker","FP_Notification_Added_Successfully_You":"Success! you will receive status updates for this flight.","FP_Owner":"Owner","FP_Status_Updates_Not_Available":"Status updates are not available for historical flights","FP_Last_Seen_Near":"last seen near","FP_Remark_Add":"Add New Remark","FP_Operator":"Operator","FP_Aviator_View_Explain":"Aviator view shows general aviation flights with runway times in the progress bar and a condensed page layout. Enable this setting to view all flights this way.","FP_Flight":"Flight","FP_Explain_Enter_Flight_Info":"Enter a flight (tail number, identifier, or airline name & number) into the search box above for live flight tracking.","FP_Few_Seconds":"a few seconds","FP_Remark_Added_Successfully":"Remark added successfully.","FP_Tour_Step_2":"Progress bar shows gate-to-gate departures and arrivals (when available)","FP_Duration_Minute":"%1 minute","FP_Manager":"Manager","FP_Tour_Step_1":"We redesigned our Flight Page. Check out the updated features!","FP_AD_Message_TTL":"Please enter a valid number of hours to retry this message for.","FP_X_Flown":"%1 flown","FP_X_To_Go":"%1 to go","FP_Tour_Step_3":"Progress bar shows take-off and landing times","FP_Tour_Step_6":"View all flights in Aviator mode","FP_Last_Seen_At":"Last seen at %1","FP_Status_Updates":"Status Updates","FP_First_Seen_At":"First seen at %1","FP_Took_Off_From":"took off from","FP_Takes_Off_From":"takes off from","FP_Landed_At":"landed at","FP_Landing_At":"landing at","FP_Not_Your_Flight":"Not your flight?","FP_Activity_Log":"Activity Log","FP_Upcoming_Flights":"Upcoming flights","FP_Date":"Date","FP_Departure":"Departure","FP_Arrival":"Arrival","FP_Aircraft":"Aircraft","FP_Duration":"Duration","FP_Enroute_Flight":"En Route flight","FP_Past_Flights":"Past flights","FP_View_More_Flight_History":"View more flight history","FP_Report_Inaccuracies":"Report inaccuracies on this page","FP_Aircraft_Type":"Aircraft Type","FP_Photos":"Photos","FP_View_All_Photos":"view all photos","FP_Details":"Details","FP_Flight_Details":"Flight Details","FP_Flight_Times":"Flight Times","FP_Takeoff":"Takeoff","FP_Landing":"Landing","FP_Actual":"Actual","FP_Scheduled":"Scheduled","FP_Elapsed":"Elapsed","FP_Remaining":"Remaining","FP_Total_Flight_Time":"Total Flight Time","FP_Track_Inbound_Plane":"Track inbound plane","FP_Departure_Times":"Departure Times","FP_Gate_Departures":"Gate Departure","FP_Taxiing":"Taxiing","FP_Estimated":"Estimated","FP_Average_Delay":"Average Delay","FP_Arrival_Times":"Arrival Times","FP_Gate_Arrival":"Gate Arrival","FP_Airline":"Airline","FP_Average_Fare":"Average Fare","FP_Cabin":"Cabin","FP_Additional_Links":"Additional Links","FP_Flight_Data":"Flight data","FP_Filed":"Filed","FP_Direct":"Direct","FP_Fuel_Burn":"Fuel Burn","FP_Route":"Route","FP_Decode":"decode","FP_Tail_Number":"Tail Number","FP_Registration":"Registration","FP_Remarks":"Remarks","FP_Edit":"edit","FP_Message_Sent_Successfully":"Message sent successfully.","FP_Seconds":"seconds","FP_Result_Unknown":"Result unknown","FP_Just_Landed":"Just landed","FP_Cancelled":"Cancelled","FP_Taxiing_Take_Off":"Taxiing for takeoff","FP_Left_Gate":"Left gate","FP_Left_Terminal":"Left terminal","FP_Upload_Photo":"upload photo","FP_A_Year":"a year","FP_Duration_Minutes":"%1 minutes","FP_Upgrade_To_See_Tail":"Upgrade account to see tail number","FP_AboutYearAgo":"about a year","FP_Duration_Hour":"%1 hour","FP_Just_Arrived":"Just arrived","FP_20m_40m":"20-40 minutes","FP_40m_1hr":"40 minutes - 1 hour","FP_MoreThanHour":"More than 1 hour","FP_10m_20m":"10-20 minutes","FP_10m":"Less than 10 minutes","FP_Duration_Hours":"%1 hours","FP_LearnMore":"learn more","FP_EstimatedArrivalTime":"estimated arrival time","FP_Duration_Hours_Minutes":"%1 hours %2 minutes","FP_A_Week":"a week","FP_AboutWeekAgo":"about a week","FP_Duration_Hour_Minute":"1 ho ...
#   </script>
#   <script crossorigin="anonymous" src="http://e1.flightcdn.com/include/7f56e5978-flightaware.js" type="text/javascript">
#   </script>
#   <script src="http://e0.flightcdn.com/ajax/ignoreall/airlines_js.rvt?locale=en_US&amp;country=US&amp;1" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var isIE10 = false;
# 			/*@cc_on
# 			if (/^10/.test(@_jscript_version)) {
# 				isIE10 = true;
# 			}
# 			@*/
#   </script>
#   <!--[if lt IE 7 ]><script type="text/javascript">var isIE6 = true;</script><![endif]-->
#   <!--[if IE 7 ]><script type="text/javascript">var isIE7 = true;</script><![endif]-->
#   <!--[if IE 8 ]><script type="text/javascript">var isIE8 = true;</script><![endif]-->
#   <!--[if IE 9 ]><script type="text/javascript">var isIE9 = true;</script><![endif]-->
#   <!-- done emit -->
#   <meta content=" flight tracker tracking status map airport" name="keywords"/>
#   <meta content=" Flight Tracker (en route flights, arrivals, departures, history) with live maps and aircraft photos" name="description"/>
#   <meta content=" ✈ 23-Aug-2016  ✈ KLGA - KORD" name="title"/>
#   <meta content=" ✈ 23-Aug-2016  ✈ KLGA - KORD ✈ FlightAware" property="og:title"/>
#   <meta content="FlightAware" property="og:site_name"/>
#   <meta content="http://flightaware.com/live/flight/AAL321/history/20160824/0130Z/KLGA/KORD" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <script type="text/javascript">
#    var nTime = 360000;
# 		var timePrev = Date.now();
# 		var timeoutquant;
# 		$(document).ready(function() {
# 			restarttimeouthandler();
#
# 			var activityHandler = function(delay) {
# 				if (delay === undefined) {
# 					delay = 60000;
# 				}
# 				/* Check if we're [delay] seconds from refreshing, if so
# 				   delay the page refresh by [delay] seconds. This prevents
# 				   the page from refreshing while someone is interacting
# 				   with the page. */
# 				var timeNow = Date.now();
# 				var timeDiff = timeNow - window.timePrev;
# 				if (nTime - timeDiff < delay) {
# 					window.nTime = delay;
# 					restarttimeouthandler();
# 					window.timePrev = timeNow;
# 				}
# 			}
#
# 			$(document).keydown(activityHandler);
# 			$(document).mousedown(activityHandler);
# 		});
#   </script>
#  </head>
#  <!--[if lt IE 7 ]><body class="ie6 ie67"><![endif]-->
#  <!--[if IE 7 ]><body class="ie7 ie67"><![endif]-->
#  <!--[if IE 8 ]><body class="ie8 ie89"><![endif]-->
#  <!--[if IE 9 ]><body class="ie9 ie89"><![endif]-->
#  <!--[if (gt IE 9)|!(IE)]><!-->
#  <body>
#   <!--<![endif]-->
#   <div id="iecountdown" style="display: none;">
#    <table class="fullWidth" style="background: url(http://e1.flightcdn.com/images/ie_warning.png) 0 top repeat-x;">
#     <tbody>
#      <tr align="justify">
#       <td align="center">
#        <strong>
#         Your browser is unsupported.
#        </strong>
#        <a href="https://www.google.com/chrome/browser/desktop/" id="ie6txt" style="font-weight: bold;" target="_blank">
#         upgrade your browser
#        </a>
#       </td>
#      </tr>
#     </tbody>
#    </table>
#   </div>
#   <nav aria-label="Main navigation" class="navBarMobile" id="mobileNavBar" role="navigation">
#    <ul class="topMenuList">
#     <li class="sp_menu_item">
#      <a href="/account/manage">
#       <i class="fa fa-plane">
#       </i>
#       Join FlightAware
#      </a>
#      <a class="topMenuWhyJoin" href="/about/account_types.rvt">
#       (Why Join?)
#      </a>
#     </li>
#     <li class="sp_menu_item">
#      <a class="loginLink" href="/account/login">
#       <i class="fa fa-sign-in">
#       </i>
#       Login
#      </a>
#     </li>
#     <li class="noHover " id="LocaleTopBoxItem">
#      <div id="LocaleTopBox">
#       <form action="http://flightaware.com/account/locale_switch.rvt" method="get" style="display: inline;">
#        <select class="localePicker" name="locale" onchange="this.form.submit();">
#         <option value="ar_SA">
#          العربية
#         </option>
#         <option value="cs_CZ">
#          Čeština
#         </option>
#         <option value="de_DE">
#          Deutsch
#         </option>
#         <option value="en_AU">
#          English (Australia)
#         </option>
#         <option value="en_CA">
#          English (Canada)
#         </option>
#         <option value="en_GB">
#          English (UK)
#         </option>
#         <option selected="selected" value="en_US">
#          English (USA)
#         </option>
#         <option value="es_ES">
#          Español (España)
#         </option>
#         <option value="es_MX">
#          Español
#         </option>
#         <option value="fi_FI">
#          Suomi
#         </option>
#         <option value="fr_CA">
#          Français (Canada)
#         </option>
#         <option value="fr_FR">
#          Français (France)
#         </option>
#         <option value="he_IL">
#          עִבְרִית
#         </option>
#         <option value="hi_IN">
#          हिन्दी
#         </option>
#         <option value="hr_HR">
#          Hrvatski
#         </option>
#         <option value="it_IT">
#          Italiano
#         </option>
#         <option value="ja_JP">
#          日本語
#         </option>
#         <option value="ko_KR">
#          한국어
#         </option>
#         <option value="pl_PL">
#          Polski
#         </option>
#         <option value="pt_BR">
#          Português (Brasil)
#         </option>
#         <option value="pt_PT">
#          Português (Portugal)
#         </option>
#         <option value="ru_RU">
#          Русский
#         </option>
#         <option value="tr_TR">
#          Türkçe
#         </option>
#         <option value="zh_CN">
#          中文(简体)
#         </option>
#         <option value="zh_HK">
#          中文(香港)
#         </option>
#         <option value="zh_TW">
#          中文(台灣)
#         </option>
#        </select>
#       </form>
#       <a href="http://flightaware.com/account/locale_switch.rvt?locale=en_US">
#        <img alt="US Flag" height="11" src="http://e1.flightcdn.com/images/countries/US.png" title="Switch to US FlightAware" width="16"/>
#       </a>
#      </div>
#     </li>
#    </ul>
#    <ul id="listMenuRootMobile" role="menubar">
#     <li aria-haspopup="true" class="menu_item" data-id="10" role="menuitem">
#      <a href="/live/">
#       Live Flight Tracking
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_live_trackingMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/findflight/">
#         Flight Finder
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/cancelled/">
#         Cancellations
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/airport/delays/">
#         Airport Delays
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/miserymap/">
#         MiseryMap
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/fleet/">
#         Browse by Operator
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/resources/airport/browse/">
#         Browse by Airport
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/aircrafttype/">
#         Browse by Aircraft Type
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/airport/random">
#         Random Airport
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/flight/random">
#         Random Flight
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/mobile">
#         Mobile Flight Tracker Apps
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/statistics/ifr-route/">
#         IFR Route Analyzer
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/resources/weather_maps/">
#         Weather
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/resources/emetar/">
#         E-metar
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="20" role="menuitem">
#      <a href="/commercial/">
#       Products
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_commercial_servicesMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/premium/">
#         Premium Accounts
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/advertising/">
#         Advertising
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/flightxml/">
#         FlightXML - Flight Status / Flight Tracking API
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/data/adsb/">
#         Firehose - Worldwide ADS-B Data Feed
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/data/surface_movement/">
#         Airport Surface Movement Data Feed
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/aireon/">
#         Global Space-Based ADS-B
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/data/">
#         Live Data Feeds
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/global/">
#         FlightAware Global
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/tv/">
#         FlightAware TV
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/customreports/">
#         Custom Reports
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/fbotoolbox">
#         FBO ToolBox
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="30" role="menuitem">
#      <a href="/adsb/">
#       ADS-B
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_adsbMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/stats">
#         Statistics
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/coverage">
#         Coverage Map
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/piaware/build">
#         Build a PiAware ADS-B Receiver
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/flightfeeder">
#         FlightFeeder ADS-B Receiver
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/faq">
#         FAQs
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/aireon/">
#         Global Space-Based ADS-B
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="40" role="menuitem">
#      <a href="/photos/">
#       Photos
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_photosMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/">
#         Popular Photos
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/browse/newest">
#         Newest Photos
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/ranked/cume">
#         Highest Ranked
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/staffpicks/cume">
#         Staff Picks
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/recentcomments.rvt?page=1">
#         Recent Comments
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="50" role="menuitem">
#      <a href="/squawks/">
#       Squawks
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_squawksMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/squawks/browse/general/recently/popular">
#         Current Squawks
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/squawks/browse/general/24_hours/new">
#         New Squawks
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/squawks/">
#         Popular Squawks
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="60" role="menuitem">
#      <a href="https://discussions.flightaware.com">
#       Discussions
#      </a>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="80" role="menuitem">
#      <a href="/about/">
#       About
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_about_flightawareMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/">
#         Overview
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/executives/">
#         Executive Profiles
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/history.rvt">
#         History
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/account_types.rvt">
#         Account Types
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/faq">
#         FAQs
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/merchandise/">
#         Company Store
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/careers/">
#         Careers
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/news/">
#         Newsroom
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="90" role="menuitem">
#      <a href="/about/contact/">
#       Contact
#      </a>
#     </li>
#     <li class="socialShare">
#      <div class="socialContainer">
#       <a class="facebook ss-icon" href="https://www.facebook.com/FlightAware">
#        
#       </a>
#       <ul class="social_submenu">
#        <li class="social_submenu_item">
#         <a class="share-button facebook-button" href="https://facebook.com/sharer.php?u=http://flightaware.com/live/flight/AAL321/history/20160824/0130Z/KLGA/KORD" target="_blank">
#          <i class="fa fa-facebook-official">
#          </i>
#          <span class="share-text">
#           Like
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="socialContainer">
#       <a class="twitter ss-icon" href="https://twitter.com/flightaware">
#        
#       </a>
#       <ul class="social_submenu">
#        <li class="social_submenu_item">
#         <a class="share-button tweet-button" href="https://twitter.com/intent/tweet?url=http://flightaware.com/live/flight/AAL321/history/20160824/0130Z/KLGA/KORD&amp;via=FlightAware" target="_blank">
#          <i class="fa fa-twitter">
#          </i>
#          <span class="share-text">
#           Tweet
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </li>
#    </ul>
#   </nav>
#   <div id="slideOutPanel">
#    <header id="topWrapper" role="banner">
#     <div class="topMenuBarWrapper">
#      <nav class="topMenuBar">
#       <ul class="topMenuList">
#        <li class="sp_menu_item">
#         <a href="/account/manage">
#          <i class="fa fa-plane">
#          </i>
#          Join FlightAware
#         </a>
#         <a class="topMenuWhyJoin" href="/about/account_types.rvt">
#          (Why Join?)
#         </a>
#        </li>
#        <li class="sp_menu_item">
#         <a class="loginLink" href="/account/login">
#          <i class="fa fa-sign-in">
#          </i>
#          Login
#         </a>
#        </li>
#        <li class="noHover " id="LocaleTopBoxItem">
#         <div id="LocaleTopBox">
#          <form action="http://flightaware.com/account/locale_switch.rvt" method="get" style="display: inline;">
#           <select class="localePicker" name="locale" onchange="this.form.submit();">
#            <option value="ar_SA">
#             العربية
#            </option>
#            <option value="cs_CZ">
#             Čeština
#            </option>
#            <option value="de_DE">
#             Deutsch
#            </option>
#            <option value="en_AU">
#             English (Australia)
#            </option>
#            <option value="en_CA">
#             English (Canada)
#            </option>
#            <option value="en_GB">
#             English (UK)
#            </option>
#            <option selected="selected" value="en_US">
#             English (USA)
#            </option>
#            <option value="es_ES">
#             Español (España)
#            </option>
#            <option value="es_MX">
#             Español
#            </option>
#            <option value="fi_FI">
#             Suomi
#            </option>
#            <option value="fr_CA">
#             Français (Canada)
#            </option>
#            <option value="fr_FR">
#             Français (France)
#            </option>
#            <option value="he_IL">
#             עִבְרִית
#            </option>
#            <option value="hi_IN">
#             हिन्दी
#            </option>
#            <option value="hr_HR">
#             Hrvatski
#            </option>
#            <option value="it_IT">
#             Italiano
#            </option>
#            <option value="ja_JP">
#             日本語
#            </option>
#            <option value="ko_KR">
#             한국어
#            </option>
#            <option value="pl_PL">
#             Polski
#            </option>
#            <option value="pt_BR">
#             Português (Brasil)
#            </option>
#            <option value="pt_PT">
#             Português (Portugal)
#            </option>
#            <option value="ru_RU">
#             Русский
#            </option>
#            <option value="tr_TR">
#             Türkçe
#            </option>
#            <option value="zh_CN">
#             中文(简体)
#            </option>
#            <option value="zh_HK">
#             中文(香港)
#            </option>
#            <option value="zh_TW">
#             中文(台灣)
#            </option>
#           </select>
#          </form>
#          <a href="http://flightaware.com/account/locale_switch.rvt?locale=en_US">
#           <img alt="US Flag" height="11" src="http://e1.flightcdn.com/images/countries/US.png" title="Switch to US FlightAware" width="16"/>
#          </a>
#         </div>
#        </li>
#        <li class="fadate-clock noHover" id="headerClock">
#         <span title="EDT">
#          02:03PM EDT
#         </span>
#        </li>
#       </ul>
#      </nav>
#     </div>
#     <div id="topContent">
#      <div class="menuIcon">
#       <i class="fa fa-bars">
#       </i>
#      </div>
#      <div class="logoLeft float_left">
#       <a href="/">
#        <img alt="FlightAware" class="faLogo " src="http://e1.flightcdn.com/images/fa_logo_white.png"/>
#       </a>
#      </div>
#      <div class="headerTrack" id="headerSearchForm">
#       <div class="flightSearchForm">
#        <div class="searchToggle text_align_right">
#         <div class="search_in">
#          <span class="search_in_content">
#           All
#          </span>
#          <select class="trackSelect">
#           <option value="omniSearch">
#            All
#           </option>
#           <option value="routeSearch">
#            Route
#           </option>
#           <option value="airlineSearch">
#            Airline flight
#           </option>
#           <option value="privateSearch">
#            Private flight (tail #)
#           </option>
#           <option value="airportSearch">
#            Airport
#           </option>
#          </select>
#         </div>
#        </div>
#        <div class="searchOption active" data-fa-search-type="omniSearch" id="omniSearch">
#         <div class="fa_omnisearch_container">
#          <form action="//flightaware.com/ajax/ignoreall/omnisearch/disambiguation.rvt" id="omnisearch_form" method="get">
#           <input name="searchterm" type="hidden" value=""/>
#           <input name="token" type="hidden" value=""/>
#           <input data-alias="flightaware.com" data-ambiguous="More results for %1 ..." data-placeholder="   Search for flight, tail, airport, or city" data-recent="Recent Searches" data-searching="Searching..." data-server="e1.flightcdn.com" data-startsearch="Please begin searching to receive suggestions" data-version="43" id="omni_headerSearchForm" tabindex="1" type="hidden"/>
#           <div class="omnisearch_loading" style="display:none;">
#            <i class="fa fa-spinner fa-pulse">
#            </i>
#           </div>
#          </form>
#         </div>
#        </div>
#        <div class="searchOption routeSearch hide text_align_left" data-fa-search-type="routeSearch">
#         <form action="/live/findflight">
#          <div class="trackInputContainer">
#           <div class="trackInput">
#            <input aria-label="Origin" class="trackRouteOrigin" name="origin" placeholder="Origin (e.g. KJFK)" tabindex="1" title="Origin (e.g. KJFK)" type="text"/>
#           </div>
#          </div>
#          <div class="route_swap">
#           <div class="header_swap">
#            <img alt="Swap" src="http://e1.flightcdn.com/images/home_main/swap_icon.png"/>
#           </div>
#          </div>
#          <div class="trackInputContainer">
#           <div class="trackInput">
#            <input aria-label="Destination " class="trackRouteDestination" name="destination" placeholder="Destination  (e.g. KLAX)" tabindex="2" title="Destination  (e.g. KLAX)" type="text"/>
#           </div>
#          </div>
#          <input hidefocus="true" style="display: none;" type="submit"/>
#         </form>
#        </div>
#        <div class="searchOption multiple hide text_align_left" data-fa-search-type="airlineSearch">
#         <form action="/live/form.rvt" class="airlineSearch">
#          <div class="trackInputContainer airlineName ">
#           <div class="trackInput">
#            <input aria-label="Airline (e.g. United)" class="trackAirlineName" id="airline_name" name="q" placeholder="Airline (e.g. United)" tabindex="2" title="Airline (e.g. United)" type="text" value=""/>
#           </div>
#          </div>
#          <div class="trackInputContainer flightNumber ">
#           <div class="trackInput">
#            <input aria-label="Flight # (e.g. 450)" class="trackAirlineNumber" id="ident_suffix" name="ident_suffix" placeholder="Flight # (e.g. 450)" tabindex="3" title="Flight # (e.g. 450)" type="text" value=""/>
#           </div>
#          </div>
#          <input id="ident_prefix" name="ident_prefix" type="hidden"/>
#          <input hidefocus="true" style="display: none;" type="submit"/>
#          <span class="fa fa-times-circle-o" id="airlineSearchCancel">
#          </span>
#         </form>
#        </div>
#        <form action="/live/form.rvt" class="searchOption hide text_align_left" data-fa-search-type="privateSearch" id="privateSearch">
#         <div class="trackInput">
#          <input aria-label="Flight/Tail# (e.g. N123AB)" class="trackTail" name="ident" placeholder="Flight/Tail# (e.g. N123AB)" tabindex="4" title="Flight/Tail# (e.g. N123AB)" type="text" value=""/>
#         </div>
#        </form>
#        <form action="/live/form.rvt" class="searchOption multiple hide text_align_left" data-fa-search-type="airportSearch" id="airportSearch">
#         <div class="trackInput">
#          <input aria-label="Airport Code (e.g. KJFK)" class="trackAirportCode" id="airport" name="airport" placeholder="Airport Code (e.g. KJFK)" tabindex="5" title="Airport Code (e.g. KJFK)" type="text" value=""/>
#         </div>
#         <div class="trackInput">
#          <input aria-label="Airport City (e.g. New York)" class="trackAirportCity" id="airport_name_or_city" name="airport_name_or_city" placeholder="Airport City (e.g. New York)" tabindex="6" title="Airport City (e.g. New York)" type="text"/>
#         </div>
#         <input hidefocus="true" style="display: none;" type="submit"/>
#        </form>
#        <div class="trackSubmit">
#         <button class="orange_button" tabindex="7" type="submit">
#          Track
#         </button>
#        </div>
#       </div>
#      </div>
#      <nav aria-label="Main navigation" class="navBar" role="navigation">
#       <ul id="listMenuRoot" role="menubar">
#        <li aria-haspopup="true" class="menu_item" data-id="10" role="menuitem">
#         <a href="/live/">
#          Live Flight Tracking
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_live_tracking" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/findflight/">
#            Flight Finder
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/cancelled/">
#            Cancellations
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/airport/delays/">
#            Airport Delays
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/miserymap/">
#            MiseryMap
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/fleet/">
#            Browse by Operator
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/resources/airport/browse/">
#            Browse by Airport
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/aircrafttype/">
#            Browse by Aircraft Type
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/airport/random">
#            Random Airport
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/flight/random">
#            Random Flight
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/mobile">
#            Mobile Flight Tracker Apps
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/statistics/ifr-route/">
#            IFR Route Analyzer
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/resources/weather_maps/">
#            Weather
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/resources/emetar/">
#            E-metar
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="20" role="menuitem">
#         <a href="/commercial/">
#          Products
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_commercial_services" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/premium/">
#            Premium Accounts
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/advertising/">
#            Advertising
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/flightxml/">
#            FlightXML - Flight Status / Flight Tracking API
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/data/adsb/">
#            Firehose - Worldwide ADS-B Data Feed
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/data/surface_movement/">
#            Airport Surface Movement Data Feed
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/aireon/">
#            Global Space-Based ADS-B
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/data/">
#            Live Data Feeds
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/global/">
#            FlightAware Global
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/tv/">
#            FlightAware TV
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/customreports/">
#            Custom Reports
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/fbotoolbox">
#            FBO ToolBox
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="30" role="menuitem">
#         <a href="/adsb/">
#          ADS-B
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_adsb" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/stats">
#            Statistics
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/coverage">
#            Coverage Map
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/piaware/build">
#            Build a PiAware ADS-B Receiver
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/flightfeeder">
#            FlightFeeder ADS-B Receiver
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/faq">
#            FAQs
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/aireon/">
#            Global Space-Based ADS-B
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="40" role="menuitem">
#         <a href="/photos/">
#          Photos
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_photos" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/">
#            Popular Photos
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/browse/newest">
#            Newest Photos
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/ranked/cume">
#            Highest Ranked
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/staffpicks/cume">
#            Staff Picks
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/recentcomments.rvt?page=1">
#            Recent Comments
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="50" role="menuitem">
#         <a href="/squawks/">
#          Squawks
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_squawks" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/squawks/browse/general/recently/popular">
#            Current Squawks
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/squawks/browse/general/24_hours/new">
#            New Squawks
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/squawks/">
#            Popular Squawks
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="60" role="menuitem">
#         <a href="https://discussions.flightaware.com">
#          Discussions
#         </a>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="80" role="menuitem">
#         <a href="/about/">
#          About
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_about_flightaware" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/">
#            Overview
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/executives/">
#            Executive Profiles
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/history.rvt">
#            History
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/account_types.rvt">
#            Account Types
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/faq">
#            FAQs
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/merchandise/">
#            Company Store
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/careers/">
#            Careers
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/news/">
#            Newsroom
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="90" role="menuitem">
#         <a href="/about/contact/">
#          Contact
#         </a>
#        </li>
#        <li class="socialShare">
#         <div class="socialContainer">
#          <a class="facebook ss-icon" href="https://www.facebook.com/FlightAware">
#           
#          </a>
#          <ul class="social_submenu">
#           <li class="social_submenu_item">
#            <a class="share-button facebook-button" href="https://facebook.com/sharer.php?u=http://flightaware.com/live/flight/AAL321/history/20160824/0130Z/KLGA/KORD" target="_blank">
#             <i class="fa fa-facebook-official">
#             </i>
#             <span class="share-text">
#              Like
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="socialContainer">
#          <a class="twitter ss-icon" href="https://twitter.com/flightaware">
#           
#          </a>
#          <ul class="social_submenu">
#           <li class="social_submenu_item">
#            <a class="share-button tweet-button" href="https://twitter.com/intent/tweet?url=http://flightaware.com/live/flight/AAL321/history/20160824/0130Z/KLGA/KORD&amp;via=FlightAware" target="_blank">
#             <i class="fa fa-twitter">
#             </i>
#             <span class="share-text">
#              Tweet
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </header>
#    <div class="pageContainer">
#     <script type="text/javascript">
#      $(function(){new FlightPage();});
#     </script>
#     <div class="flightPageAd flightPageNewAdUnit" data-set="flightPageAds">
#     </div>
#     <div class="flightPageContainer">
#      <div class="flightPageBlockedData" data-template="live/flight/blocked">
#      </div>
#      <div class="flightPageUnknownData" data-template="live/flight/unknown">
#      </div>
#      <div class="flightPageSummaryMap">
#       <div data-template="live/flight/summary">
#       </div>
#       <div data-template="live/flight/summaryLinks">
#       </div>
#       <div data-template="live/flight/airportDelays">
#       </div>
#       <div data-template="live/flight/adhoc">
#       </div>
#       <div class="flightPageMapContainer" id="flightPageTourStepMap">
#        <div id="flightPageInteractiveMap" style="width:100%; height:600px;">
#        </div>
#        <div class="flightPageStaticMapContainer" data-server="flightxml.flightaware.com">
#         <div class="flightPageStaticMap" data-disable-refresh="true" data-template="live/flight/staticMap">
#         </div>
#         <div class="flightPageNotificationContainer" data-template="live/flight/notification">
#         </div>
#        </div>
#       </div>
#       <div class="flightPageSummaryMapDetails">
#        <div data-template="live/flight/airline">
#        </div>
#        <div data-template="live/flight/data">
#        </div>
#       </div>
#       <div class="flightPageActivityLogTop" data-set="flightPageRemarksActivityLog">
#        <div class="remarksAndActivityLog" data-template="live/flight/positionOnly" id="flightPagePositionOnly">
#        </div>
#        <div class="flightPageActivityLog remarksAndActivityLog" data-template="live/flight/log" id="flightPageActivityLog">
#        </div>
#       </div>
#      </div>
#      <div class="flightPageDetails">
#       <div class="flightPageCondensedSummary" data-template="live/flight/summary">
#       </div>
#       <div class="flightPageSponsorshipAd viewableAdHome" data-set="flightPageAds">
#        <div class="flightPageAdUnit">
#         <script>
#          var googletag = googletag || {};
# 			googletag.cmd = googletag.cmd || [];
# 			(function() {
# 				var gads = document.createElement('script');
# 				gads.async = true;
# 				gads.type = 'text/javascript';
# 				var useSSL = 'https:' == document.location.protocol;
# 				gads.src = (useSSL ? 'https:' : 'http:') +
# 				'//www.googletagservices.com/tag/js/gpt.js';
# 				var node = document.getElementsByTagName('script')[0];
# 				node.parentNode.insertBefore(gads, node);
# 			})();
# 			if (typeof googletag.enableSingleRequest === 'function') {
# 				googletag.cmd.push(function() { googletag.enableSingleRequest(); });
# 			}
# 			var displayGoogleAd = function(id) { googletag.display(id); }
#         </script>
#         <script>
#          googletag.cmd.push(function() {
# 					var mapping = googletag.sizeMapping().addSize([0,0], [[320,50]]).addSize([768,0], [[300,250]]).build();
# 					googletag.defineSlot('/6254/flight.main/live/flight/atf', [[300,250]], 'FA_ads_250311').defineSizeMapping(mapping).addService(googletag.pubads()).setTargeting('aircraft_type', '').setTargeting('dcove', 'd').setTargeting('ident', '').setTargeting('lang', 'en').setTargeting('locale', 'en_US').setTargeting('suffix', '').setTargeting('type', 'ros').setTargeting('unitName', 'flight').setTargeting('userGen', 'f');
# 					googletag.pubads().setCentering(true);
# 					googletag.enableServices();
# 				});
#         </script>
#         <div class="fa-google-ad" id="FA_ads_250311" style="min-height:250px;">
#         </div>
#        </div>
#       </div>
#       <div class="flightPageNotificationContainer" data-template="live/flight/notification">
#       </div>
#       <div data-template="live/flight/airportDelays">
#       </div>
#       <div data-template="live/flight/details">
#       </div>
#       <div data-template="live/flight/airline">
#       </div>
#       <div data-template="live/flight/data">
#       </div>
#       <div data-disable-refresh="true" data-template="live/flight/thumbnailCarousel">
#       </div>
#       <div class="flightPageYieldMoAd" data-set="flightPageAdsBottom">
#       </div>
#       <div class="flightPageRemarks remarksAndActivityLog" data-template="live/flight/remarks">
#       </div>
#       <div class="flightPageReportInaccuraciesRight" data-set="flightPageReportInaccuracies">
#       </div>
#       <div class="flightPageSponsorshipAd">
#       </div>
#      </div>
#      <div class="flightPageActivityLogBottom" data-set="flightPageRemarksActivityLog">
#      </div>
#      <div class="flightPageReportInaccuraciesBottom" data-set="flightPageReportInaccuracies">
#       <div class="flightPageReportInaccuracies" data-disable-refresh="true" data-template="live/flight/reportInaccuracies">
#       </div>
#      </div>
#      <div data-disable-refresh="true" data-template="live/flight/modal/notifications">
#      </div>
#      <div data-disable-refresh="true" data-template="live/flight/modal/settings">
#      </div>
#      <div data-disable-refresh="true" data-template="live/flight/modal/remark">
#      </div>
#     </div>
#     <div class="flightPageAdBottom flightPageNewAdUnit" data-set="flightPageAdsBottom">
#      <div class="flightPageAdUnit">
#       <script>
#        googletag.cmd.push(function() {
# 					var mapping = googletag.sizeMapping().addSize([0,0], [[300,250],[320,180]]).addSize([768,0], [[728,90]]).addSize([970,0], [[970,90],[728,90]]).build();
# 					googletag.defineSlot('/6254/flight.main/live/flight/btf', [[728,90]], 'FA_ads_991751').defineSizeMapping(mapping).addService(googletag.pubads()).setTargeting('aircraft_type', '').setTargeting('dcove', 'd').setTargeting('ident', '').setTargeting('lang', 'en').setTargeting('locale', 'en_US').setTargeting('suffix', '').setTargeting('type', 'ros').setTargeting('unitName', 'flight').setTargeting('userGen', 'f');
# 					googletag.pubads().setCentering(true);
# 					googletag.enableServices();
# 				});
#       </script>
#       <div class="fa-google-ad" id="FA_ads_991751" style="min-height:90px;">
#       </div>
#      </div>
# ...
#   </script>
#   <script data-tpl="live/flight/data" type="text/javascript">
#    !function(){var a=Handlebars.template,l=Handlebars.templates=Handlebars.templates||{};l.data=a({1:function(a,l,n,e,t){return"flightPageAviatorView"},3:function(a,l,n,e,t){var i,s=null!=l?l:{},c=n.helperMissing;return'<div class="flightPageData">\n'+a.escapeExpression((n.formatSpeed||l&&l.formatSpeed||c).call(s,null!=l?l.groundspeed:l,{name:"formatSpeed",hash:{},data:t}))+" "+(null!=(i=n.if.call(s,null!=(i=null!=l?l.flightPlan:l)?i.speed:i,{name:"if",hash:{},fn:a.program(4,t,0),inverse:a.noop,data:t}))?i:"")+'\n</div>\n<div class="flightPageData">\n'+(null!=(i=n.if.call(s,(n.coalesce||l&&l.coalesce||c).call(s,null!=(i=null!=(i=null!=l?l.codeShare:l)?i.links:i)?i.trackLog:i,null!=(i=null!=l?l.links:l)?i.trackLog:i,{name:"coalesce",hash:{},data:t}),{name:"if",hash:{},fn:a.program(6,t,0),inverse:a.noop,data:t}))?i:"")+"</div>\n"},4:function(a,l,n,e,t){var i,s=null!=l?l:{},c=n.helperMissing,r=a.escapeExpression;return"(<em>"+r((n.mc||l&&l.mc||c).call(s,"FP_Planned","Planned",{name:"mc",hash:{},data:t}))+": "+r((n.formatSpeed||l&&l.formatSpeed||c).call(s,null!=(i=null!=l?l.flightPlan:l)?i.speed:i,{name:"formatSpeed",hash:{},data:t}))+"</em>)"},6:function(a,l,n,e,t){var i;return'<a href="'+a.escapeExpression((n.coalesce||l&&l.coalesce||n.helperMissing).call(null!=l?l:{},null!=(i=null!=(i=null!=l?l.codeShare:l)?i.links:i)?i.trackLog:i,null!=(i=null!=l?l.links:l)?i.trackLog:i,{name:"coalesce",hash:{},data:t}))+'" class="flightPageLink">graph</a>\n'},8:function(a,l,n,e,t){var i;return null!=(i=n.if.call(null!=l?l:{},null!=(i=null!=l?l.flightPlan:l)?i.speed:i,{name:"if",hash:{},fn:a.program(9,t,0),inverse:a.program(11,t,0),data:t}))?i:""},9:function(a,l,n,e,t){var i,s=null!=l?l:{},c=n.helperMissing,r=a.escapeExpression;return'<div class="flightPageData">\n'+r((n.mc||l&&l.mc||c).call(s,"FP_Filed","Filed",{name:"mc",hash:{},data:t}))+": "+r((n.formatSpeed||l&&l.formatSpeed||c).call(s,null!=(i=null!=l?l.flightPlan:l)?i.speed:i,{name:"formatSpeed",hash:{},data:t}))+'\n</div>\n<div class="flightPageData">\n'+(null!=(i=n.if.call(s,(n.coalesce||l&&l.coalesce||c).call(s,null!=(i=null!=(i=null!=l?l.codeShare:l)?i.links:i)?i.trackLog:i,null!=(i=null!=l?l.links:l)?i.trackLog:i,{name:"coalesce",hash:{},data:t}),{name:"if",hash:{},fn:a.program(6,t,0),inverse:a.noop,data:t}))?i:"")+"</div>\n"},11:function(a,l,n,e,t){return'<div class="flightPageData">&mdash;</div>\n<div class="flightPageData"></div>\n'},13:function(a,l,n,e,t){var i,s=null!=l?l:{},c=n.helperMissing;return'<div class="flightPageData">\n'+(null!=(i=n.if.call(s,(n.eq||l&&l.eq||c).call(s,null!=l?l.altitudeChange:l,"C",{name:"eq",hash:{},data:t}),{name:"if",hash:{},fn:a.program(14,t,0),inverse:a.program(16,t,0),data:t}))?i:"")+a.escapeExpression((n.formatAltitude||l&&l.formatAltitude||c).call(s,null!=l?l.altitude:l,{name:"formatAltitude",hash:{},data:t}))+" "+(null!=(i=n.if.call(s,null!=(i=null!=l?l.flightPlan:l)?i.altitude:i,{name:"if",hash:{},fn:a.program(19,t,0),inverse:a.noop,data:t}))?i:"")+'\n</div>\n<div class="flightPageData">\n'+(null!=(i=n.if.call(s,(n.coalesce||l&&l.coalesce||c).call(s,null!=(i=null!=(i=null!=l?l.codeShare:l)?i.links:i)?i.trackLog:i,null!=(i=null!=l?l.links:l)?i.trackLog:i,{name:"coalesce",hash:{},data:t}),{name:"if",hash:{},fn:a.program(6,t,0),inverse:a.noop,data:t}))?i:"")+"</div>\n"},14:function(a,l,n,e,t){return'<svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 10 10" class="flightPageDataAltitudeIcon"><defs><style>.flightPageDataAltitudeIconFill{fill:#002f5d;}</style></defs><title>alt-ascend</title><g id="Layer_2" data-name="Layer 2"><g id="_300_AD" data-name="300 AD"><polygon class="flightPageDataAltitudeIconFill" points="2.48 0 10 0 10 7.52 7.52 10 7.52 4.28 1.91 9.9 0.09 8.08 5.68 2.48 0 2.48 2.48 0"/></g></g></svg>\n'},16:function(a,l,n,e,t){var i,s=null!=l?l:{};return null!=(i=n.if.call(s,(n.eq||l&&l.eq||n.helperMissing).call(s,null!=l?l.altitudeChange:l,"D",{name:"eq",hash:{},data:t}),{name:"if",hash:{},fn:a.program(17,t,0),inverse:a.noop,data:t} ...
#   </script>
#   <script data-tpl="live/flight/reportInaccuracies" type="text/javascript">
#    !function(){var a=Handlebars.template,e=Handlebars.templates=Handlebars.templates||{};e.reportInaccuracies=a({1:function(a,e,t,i,l){return'<p>Please provide an email address where we can contact you for more information:</p>\n<input type="email" name="email" id="flightPageReportEmail" class="flightPageReportEmail">\n'},compiler:[7,">= 4.0.0"],main:function(a,e,t,i,l){var n,r=null!=e?e:{},o=t.helperMissing,s=a.escapeExpression;return'<!-- Report inaccuracies -->\n\n<h3 id="flightPageReportPanel" class="flightPageDataTableHeading" data-collapsible="true"><i class="fa fa-plus-square" aria-hidden="true"></i> <span>'+s((t.mc||e&&e.mc||o).call(r,"FP_Report_Inaccuracies","Report inaccuracies on this page",{name:"mc",hash:{},data:l}))+'</span></h3>\n\n\n<div class="flightPageReportInaccuraciesForm flightPageDataTable" id="flightPageReportInaccuraciesForm">\n<form id="reportInaccuracies" method="post" action="'+s(a.lambda(null!=(n=null!=e?e.links:e)?n.reportInaccuracies:n,e))+'" enctype="multipart/form-data">\n<input type="hidden" name="json_report" id="json_report" value="">\n<input type="radio" name="errorRadio" id="times" value="times">\n<input type="radio" name="errorRadio" id="airports" value="airports">\n<input type="radio" name="errorRadio" id="aircraft_type" value="aircraft_type">\n<input type="radio" name="errorRadio" id="path" value="path">\n<input type="radio" name="errorRadio" id="not_cancelled" value="not_cancelled">\n<input type="radio" name="errorRadio" id="cancelled" value="cancelled">\n<input type="radio" name="errorRadio" id="other" value="other">\n<h3 class="flightPageDataTableHeading">Please Identify The Issue</h3>\n<div class="flightPageDataTable">\n<div class="flightPageDataRow">\n<label for="times" class="flightPageReportType">Inaccurate arrival/departure time</label>\n</div>\n<div class="flightPageDataRow">\n<label for="airports" class="flightPageReportType">Inaccurate origin/destination airport</label>\n</div>\n<div class="flightPageDataRow">\n<label for="aircraft_type" class="flightPageReportType">Inaccurate aircraft type</label>\n</div>\n<div class="flightPageDataRow">\n<label for="path" class="flightPageReportType">Inaccurate depicted flight path on map</label>\n</div>\n<div class="flightPageDataRow">\n<label for="not_cancelled" class="flightPageReportType">Flight was shown as canceled, but actually operated</label>\n</div>\n<div class="flightPageDataRow">\n<label for="cancelled" class="flightPageReportType">Flight should have been shown as canceled</label>\n</div>\n<div class="flightPageDataRow">\n<label for="other" class="flightPageReportType">Other (please explain below)</label>\n</div>\n</div>\n<div class="flightPageReportDetails">\n<div class="flightPageReportComments">\n<p>Please provide any additional clarifying information:</p>\n<textarea class="flightPageReportTextarea" id="flightPageReportTextarea" name="clarification"></textarea>\n</div>\n<div class="flightPageReportEmailAndFile">\n'+(null!=(n=t.unless.call(r,(t.isLoggedIn||e&&e.isLoggedIn||o).call(r,{name:"isLoggedIn",hash:{},data:l}),{name:"unless",hash:{},fn:a.program(1,l,0),inverse:a.noop,data:l}))?n:"")+'<p>If possible, upload a screenshot or image demonstrating the issue: <input type="file" name="media" class="flightPageReportFile" id="flightPageReportFile"></p>\n\n\n<p class="flightPageReportButton"><a href="#" class="flightPageButton" data-action="reportInaccuracies"><span>Submit Report</span></a></p>\n</div>\n</div>\n</form>\n</div>'},useData:!0})}();
#   </script>
#   <script data-tpl="live/flight/positionOnly" type="text/javascript">
#    !function(){var e=Handlebars.template,n=Handlebars.templates=Handlebars.templates||{};n.positionOnly=e({1:function(e,n,a,i,s){var l,t=null!=n?n:{};return null!=(l=a.if.call(t,(a.suggestAdhoc||n&&n.suggestAdhoc||a.helperMissing).call(t,{name:"suggestAdhoc",hash:{},data:s}),{name:"if",hash:{},fn:e.program(2,s,0),inverse:e.noop,data:s}))?l:""},2:function(e,n,a,i,s){var l,t=null!=n?n:{},r=a.helperMissing;return'<div id="suggestAdhocNotice" class="flightPageAdhocNotice">\n<p><strong>'+e.escapeExpression((a.mc||n&&n.mc||r).call(t,"FP_Hidden_Flights_Summary","There are flights hidden from view because they were not matched with a flight plan.",{name:"mc",hash:{},data:s}))+"</strong></p>\n"+(null!=(l=a.if.call(t,(a.isActiveUser||n&&n.isActiveUser||r).call(t,{name:"isActiveUser",hash:{},data:s}),{name:"if",hash:{},fn:e.program(3,s,0),inverse:e.program(5,s,0),data:s}))?l:"")+"</div>\n"},3:function(e,n,a,i,s){return'<a id="showAdhoc" href="javascript:void(0)">'+e.escapeExpression((a.mc||n&&n.mc||a.helperMissing).call(null!=n?n:{},"FP_Hidden_Flights_View","View all hidden position-only flights",{name:"mc",hash:{},data:s}))+"</a>\n"},5:function(e,n,a,i,s){var l,t=null!=n?n:{};return null!=(l=a.if.call(t,(a.isLoggedIn||n&&n.isLoggedIn||a.helperMissing).call(t,{name:"isLoggedIn",hash:{},data:s}),{name:"if",hash:{},fn:e.program(6,s,0),inverse:e.program(8,s,0),data:s}))?l:""},6:function(e,n,a,i,s){return"<p><strong>"+e.escapeExpression((a.mc||n&&n.mc||a.helperMissing).call(null!=n?n:{},"FP_Hidden_Flights_Act_Account","%1Activate%2 your account to show position-only flights.",'<a href="/account/act">',"</a>",{name:"mc",hash:{},data:s}))+"</strong></p>\n"},8:function(e,n,a,i,s){var l,t=null!=n?n:{},r=a.helperMissing;return'<a id="redirectAdhoc" href="'+(null!=(l=(a.refererLink||n&&n.refererLink||r).call(t,"/account/login",{name:"refererLink",hash:{},data:s}))?l:"")+'">'+e.escapeExpression((a.mc||n&&n.mc||r).call(t,"FP_Hidden_Flights_Login","Login or create an account to view hidden flights",{name:"mc",hash:{},data:s}))+"</a>\n"},compiler:[7,">= 4.0.0"],main:function(e,n,a,i,s){var l;return"<!-- Notification to enable position-only flights -->\n"+(null!=(l=a.unless.call(null!=n?n:{},null!=n?n.adhoc:n,{name:"unless",hash:{},fn:e.program(1,s,0),inverse:e.noop,data:s}))?l:"")},useData:!0})}();
#   </script>
#   <script data-tpl="live/flight/notificationButton_partial" type="text/javascript">
#    !function(){var a=Handlebars.template;Handlebars.templates=Handlebars.templates||{};Handlebars.partials.notificationButton_partial=a({1:function(a,n,t,i,l){var o,e=null!=n?n:{},s=t.helperMissing,c="function",r=a.escapeExpression;return'<a href="'+r((o=null!=(o=t.notificationUrl||(null!=n?n.notificationUrl:n))?o:s,typeof o===c?o.call(e,{name:"notificationUrl",hash:{},data:l}):o))+'" class="'+r((o=null!=(o=t.notificationClasses||(null!=n?n.notificationClasses:n))?o:s,typeof o===c?o.call(e,{name:"notificationClasses",hash:{},data:l}):o))+'">'+r((o=null!=(o=t.notificationContent||(null!=n?n.notificationContent:n))?o:s,typeof o===c?o.call(e,{name:"notificationContent",hash:{},data:l}):o))+"</a>\n"},3:function(a,n,t,i,l){var o,e=null!=n?n:{};return null!=(o=t.if.call(e,(t.hasArrived||n&&n.hasArrived||t.helperMissing).call(e,{name:"hasArrived",hash:{},data:l}),{name:"if",hash:{},fn:a.program(4,l,0),inverse:a.program(6,l,0),data:l}))?o:""},4:function(a,n,t,i,l){var o,e=null!=n?n:{},s=t.helperMissing,c="function",r=a.escapeExpression;return'<a href="'+r((o=null!=(o=t.notificationUrl||(null!=n?n.notificationUrl:n))?o:s,typeof o===c?o.call(e,{name:"notificationUrl",hash:{},data:l}):o))+'" class="'+r((o=null!=(o=t.notificationClasses||(null!=n?n.notificationClasses:n))?o:s,typeof o===c?o.call(e,{name:"notificationClasses",hash:{},data:l}):o))+'" data-reveal-id="flightPageNotificationModal" title="'+r((t.mc||n&&n.mc||s).call(e,"FP_Status_Updates_Not_Available","Status updates are not available for historical flights.",{name:"mc",hash:{},data:l}))+'">'+r((o=null!=(o=t.notificationContent||(null!=n?n.notificationContent:n))?o:s,typeof o===c?o.call(e,{name:"notificationContent",hash:{},data:l}):o))+"</a>\n"},6:function(a,n,t,i,l){var o,e=null!=n?n:{},s=t.helperMissing,c="function",r=a.escapeExpression;return'<a href="'+r((o=null!=(o=t.notificationUrl||(null!=n?n.notificationUrl:n))?o:s,typeof o===c?o.call(e,{name:"notificationUrl",hash:{},data:l}):o))+'" class="'+r((o=null!=(o=t.notificationClasses||(null!=n?n.notificationClasses:n))?o:s,typeof o===c?o.call(e,{name:"notificationClasses",hash:{},data:l}):o))+'" data-reveal-id="flightPageNotificationModal">'+r((o=null!=(o=t.notificationContent||(null!=n?n.notificationContent:n))?o:s,typeof o===c?o.call(e,{name:"notificationContent",hash:{},data:l}):o))+"</a>\n"},compiler:[7,">= 4.0.0"],main:function(a,n,t,i,l){var o;return null!=(o=t.if.call(null!=n?n:{},null!=n?n.ga:n,{name:"if",hash:{},fn:a.program(1,l,0),inverse:a.program(3,l,0),data:l}))?o:""},useData:!0})}();
#   </script>
#   <script>
#    $(window).one('createMap.flightPageInteractiveMap', function(){
# 				FAMap_1_promise = FAMap.factory('flightPageInteractiveMap', function(){ return FAMap.Util.ConfigPresets.getFullConfig('flight', {"groups":["anonUsers","earthcastUsers","aviationCharts"],"FAS":false,"defaultExtent":[-13854058.502631625161,3130860.6785608194768,-8022830.4888120982796,6457400.1495316904038],"analytics":"Google"}) });
# 			});
#   </script>
#   <script type="text/javascript">
#    $(function() {
# 			$("body").append("<iframe src='/ajax/ignoreall/hash2.rvt?k=travel,flight,American Airlines Inc.' style='display: none;'></iframe>");
# 		});
#   </script>
#   <script>
#    var trackpollBootstrap = {"version":"2.0","summary":false,"flights":{"INVALID-1506967395362487":{"unknown":true,"unknownContent":"<div class=\"blue bignotice\">\n\t\t <h3>FlightAware couldn't find flight tracking data for <em>AAL321</em>  just yet.</h3>\n\t\t <p>\n\t\t  The link you have is for a specific flight on a specific date and airport pair.\n\t\t  <a href=\"/live/flight/AAL321\">Click here to track the most recent flight for AAL321.</a>\n\t\t  </p></div>"}}};
#   </script>
#   <script crossorigin="anonymous" src="http://e1.flightcdn.com/include/6247bc739-maps/TrackPollClient.js" type="text/javascript">
#   </script>
#   <script>
#    var trackpollGlobals = {"TOKEN":"c35ca45ecbca57cd1ea443d1c65c36426ea06630de026ffd737977e4a40a26ead614b3f2ddde9907453c214a859f7965-dd1320656957446e5ca0b3670908242463481c44d1d39a6047985654d10df2942af08e78c2c6462beffc2a80a6a9a1e2-2aa81f71c1b6e4ac05863b891f86176b43e3c172","INTERVAL":65,"SINGLE_FLIGHT":true,"USERTOKEN":""};
#   </script>
#   <script type="text/javascript">
#    (function(FA) { FA.headerSearch = (function() { var flightSearchForm = new FA.Modules.UI.FlightSearchForm('headerSearchForm', { 'stateSelectorClass' : '.trackSelect' , 'dashboardView' : 'toggle' } ); flightSearchForm.init();  return flightSearchForm; })(); })(FA);
#   </script>
#   <script type="text/javascript">
#    $("#headerSearchForm .flightSearchForm").append('<div class="forgot"><a href="/live/findflight/" > FORGOT the FLIGHT  NUMBER? </a></div>');
#   </script>
#   <script crossorigin="anonymous" src="http://e1.flightcdn.com/include/9fefb032d-flightpage/model.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
print(soup_c.prettify())
# Out:
# <!DOCTYPE html>
# <html class="responsive-full" dir="LTR" lang="en">
#  <!--
# Looking at the source?  Great!
#   FlightAware is looking for UI/UX, web, and backend developers, mathematicians and electrical engineers.
#
# Get in touch with us:
# https://flightaware.com/about/careers
#
# -->
#  <head>
#   <!-- 	Attention! You must agree with FlightAware's Terms of Use at http://flightaware.com/about/termsofuse
#   Data robots and collection agents should use http://flightaware.com/commercial/flightxml/
#             Copyright 2017 FlightAware.  All Rights Reserved. -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="@FlightAware" name="twitter:site"/>
#   <title>
#    American Airlines (AA)  #321 ✈ 22-Aug-2017  ✈ KLGA - KORD ✈ FlightAware
#   </title>
#   <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/>
#   <link href="/opensearch.xml" rel="search" title="FlightAware" type="application/opensearchdescription+xml"/>
#   <link href="http://e0.flightcdn.com/images/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#   <!-- non scripts -->
#   <link href="http://e0.flightcdn.com/include/0d5859c97-flightpage/flightpage.css" rel="stylesheet" type="text/css"/>
#   <link href="http://e0.flightcdn.com/include/0d5859c97-foundation/foundation.css" rel="stylesheet" type="text/css"/>
#   <link href="http://e1.flightcdn.com/include/0d5859c97-flightaware.css" rel="stylesheet" type="text/css"/>
#   <script>
#    if(typeof window.performance === 'object' && typeof window.performance.navigation === 'object' && window.performance.navigation.type == 2) {
# 											location.reload();
# 										}
#   </script>
#   <meta content="AAL" name="airline"/>
#   <meta content="KORD" name="destination"/>
#   <meta content="KLGA" name="origin"/>
#   <meta content="B738" name="aircrafttype"/>
#   <!--[if lt IE 9]>
# <script>
# document.createElement('header');
# document.createElement('nav');
# document.createElement('section');
# document.createElement('article');
# document.createElement('aside');
# document.createElement('footer');
# document.createElement('hgroup');
# </script>
# <![endif]-->
#   <!-- scripts -->
#   <script type="text/javascript">
#    user = {"username":"","TZ":":America/New_York","accounttype":"0","email":"","id":"","locale":"en_US","lang":"en","name":" ","active":"","arincUser":false,"fboUser":false,"distance_units":"sm","airportCode":"","altitudeDisplay":"feet","speedDisplay":"miles","fuelBurnDisplay":"gallons","flightpageLayout":"0","comma":",","decimal":".","adhocEnabled":false};
#   </script>
#   <script type="text/javascript">
#    var FAIntegrationConfig = {"enabled":false,"idents":[]};
#   </script>
#   <script type="text/javascript">
#    var airportNamesUrl = 'http://e0.flightcdn.com/ajax/ignoreall/airport_names_yajl.rvt', airportValidateUrl = 'http://e1.flightcdn.com/ajax/validate_airport.rvt';
#   </script>
#   <script>
#    var rosettaBootstrap = {"FP_Link_All_Flights":"all flights","FP_Tour_The_Page":"Tour the page","FP_Header_Live_Flight_Tracker":"Live Flight Tracker","FP_Notification_Added_Successfully_You":"Success! you will receive status updates for this flight.","FP_Owner":"Owner","FP_Status_Updates_Not_Available":"Status updates are not available for historical flights","FP_Last_Seen_Near":"last seen near","FP_Remark_Add":"Add New Remark","FP_Operator":"Operator","FP_Aviator_View_Explain":"Aviator view shows general aviation flights with runway times in the progress bar and a condensed page layout. Enable this setting to view all flights this way.","FP_Flight":"Flight","FP_Explain_Enter_Flight_Info":"Enter a flight (tail number, identifier, or airline name & number) into the search box above for live flight tracking.","FP_Few_Seconds":"a few seconds","FP_Remark_Added_Successfully":"Remark added successfully.","FP_Tour_Step_2":"Progress bar shows gate-to-gate departures and arrivals (when available)","FP_Duration_Minute":"%1 minute","FP_Manager":"Manager","FP_Tour_Step_1":"We redesigned our Flight Page. Check out the updated features!","FP_AD_Message_TTL":"Please enter a valid number of hours to retry this message for.","FP_X_Flown":"%1 flown","FP_X_To_Go":"%1 to go","FP_Tour_Step_3":"Progress bar shows take-off and landing times","FP_Tour_Step_6":"View all flights in Aviator mode","FP_Last_Seen_At":"Last seen at %1","FP_Status_Updates":"Status Updates","FP_First_Seen_At":"First seen at %1","FP_Took_Off_From":"took off from","FP_Takes_Off_From":"takes off from","FP_Landed_At":"landed at","FP_Landing_At":"landing at","FP_Not_Your_Flight":"Not your flight?","FP_Activity_Log":"Activity Log","FP_Upcoming_Flights":"Upcoming flights","FP_Date":"Date","FP_Departure":"Departure","FP_Arrival":"Arrival","FP_Aircraft":"Aircraft","FP_Duration":"Duration","FP_Enroute_Flight":"En Route flight","FP_Past_Flights":"Past flights","FP_View_More_Flight_History":"View more flight history","FP_Report_Inaccuracies":"Report inaccuracies on this page","FP_Aircraft_Type":"Aircraft Type","FP_Photos":"Photos","FP_View_All_Photos":"view all photos","FP_Details":"Details","FP_Flight_Details":"Flight Details","FP_Flight_Times":"Flight Times","FP_Takeoff":"Takeoff","FP_Landing":"Landing","FP_Actual":"Actual","FP_Scheduled":"Scheduled","FP_Elapsed":"Elapsed","FP_Remaining":"Remaining","FP_Total_Flight_Time":"Total Flight Time","FP_Track_Inbound_Plane":"Track inbound plane","FP_Departure_Times":"Departure Times","FP_Gate_Departures":"Gate Departure","FP_Taxiing":"Taxiing","FP_Estimated":"Estimated","FP_Average_Delay":"Average Delay","FP_Arrival_Times":"Arrival Times","FP_Gate_Arrival":"Gate Arrival","FP_Airline":"Airline","FP_Average_Fare":"Average Fare","FP_Cabin":"Cabin","FP_Additional_Links":"Additional Links","FP_Flight_Data":"Flight data","FP_Filed":"Filed","FP_Direct":"Direct","FP_Fuel_Burn":"Fuel Burn","FP_Route":"Route","FP_Decode":"decode","FP_Tail_Number":"Tail Number","FP_Registration":"Registration","FP_Remarks":"Remarks","FP_Edit":"edit","FP_Message_Sent_Successfully":"Message sent successfully.","FP_Seconds":"seconds","FP_Result_Unknown":"Result unknown","FP_Just_Landed":"Just landed","FP_Cancelled":"Cancelled","FP_Taxiing_Take_Off":"Taxiing for takeoff","FP_Left_Gate":"Left gate","FP_Left_Terminal":"Left terminal","FP_Upload_Photo":"upload photo","FP_A_Year":"a year","FP_Duration_Minutes":"%1 minutes","FP_Upgrade_To_See_Tail":"Upgrade account to see tail number","FP_AboutYearAgo":"about a year","FP_Duration_Hour":"%1 hour","FP_Just_Arrived":"Just arrived","FP_20m_40m":"20-40 minutes","FP_40m_1hr":"40 minutes - 1 hour","FP_MoreThanHour":"More than 1 hour","FP_10m_20m":"10-20 minutes","FP_10m":"Less than 10 minutes","FP_Duration_Hours":"%1 hours","FP_LearnMore":"learn more","FP_EstimatedArrivalTime":"estimated arrival time","FP_Duration_Hours_Minutes":"%1 hours %2 minutes","FP_A_Week":"a week","FP_AboutWeekAgo":"about a week","FP_Duration_Hour_Minute":"1 ho ...
#   </script>
#   <script crossorigin="anonymous" src="http://e1.flightcdn.com/include/7f56e5978-flightaware.js" type="text/javascript">
#   </script>
#   <script src="http://e0.flightcdn.com/ajax/ignoreall/airlines_js.rvt?locale=en_US&amp;country=US&amp;1" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var isIE10 = false;
# 			/*@cc_on
# 			if (/^10/.test(@_jscript_version)) {
# 				isIE10 = true;
# 			}
# 			@*/
#   </script>
#   <!--[if lt IE 7 ]><script type="text/javascript">var isIE6 = true;</script><![endif]-->
#   <!--[if IE 7 ]><script type="text/javascript">var isIE7 = true;</script><![endif]-->
#   <!--[if IE 8 ]><script type="text/javascript">var isIE8 = true;</script><![endif]-->
#   <!--[if IE 9 ]><script type="text/javascript">var isIE9 = true;</script><![endif]-->
#   <!-- done emit -->
#   <meta content="American Airlines (AA)  #321 Flight Tracker AAL321" name="keywords"/>
#   <meta content="American Airlines (AA)  #321 Flight Tracker (AAL321)" name="description"/>
#   <meta content="American Airlines (AA)  #321 ✈ 22-Aug-2017  ✈ KLGA - KORD" name="title"/>
#   <meta content="American Airlines (AA)  #321 ✈ 22-Aug-2017  ✈ KLGA - KORD ✈ FlightAware" property="og:title"/>
#   <meta content="FlightAware" property="og:site_name"/>
#   <meta content="http://flightaware.com/live/flight/AAL321/history/20170823/0130Z/KLGA/KORD" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <script type="text/javascript">
#    var nTime = 360000;
# 		var timePrev = Date.now();
# 		var timeoutquant;
# 		$(document).ready(function() {
# 			restarttimeouthandler();
#
# 			var activityHandler = function(delay) {
# 				if (delay === undefined) {
# 					delay = 60000;
# 				}
# 				/* Check if we're [delay] seconds from refreshing, if so
# 				   delay the page refresh by [delay] seconds. This prevents
# 				   the page from refreshing while someone is interacting
# 				   with the page. */
# 				var timeNow = Date.now();
# 				var timeDiff = timeNow - window.timePrev;
# 				if (nTime - timeDiff < delay) {
# 					window.nTime = delay;
# 					restarttimeouthandler();
# 					window.timePrev = timeNow;
# 				}
# 			}
#
# 			$(document).keydown(activityHandler);
# 			$(document).mousedown(activityHandler);
# 		});
#   </script>
#  </head>
#  <!--[if lt IE 7 ]><body class="ie6 ie67"><![endif]-->
#  <!--[if IE 7 ]><body class="ie7 ie67"><![endif]-->
#  <!--[if IE 8 ]><body class="ie8 ie89"><![endif]-->
#  <!--[if IE 9 ]><body class="ie9 ie89"><![endif]-->
#  <!--[if (gt IE 9)|!(IE)]><!-->
#  <body>
#   <!--<![endif]-->
#   <div id="iecountdown" style="display: none;">
#    <table class="fullWidth" style="background: url(http://e1.flightcdn.com/images/ie_warning.png) 0 top repeat-x;">
#     <tbody>
#      <tr align="justify">
#       <td align="center">
#        <strong>
#         Your browser is unsupported.
#        </strong>
#        <a href="https://www.google.com/chrome/browser/desktop/" id="ie6txt" style="font-weight: bold;" target="_blank">
#         upgrade your browser
#        </a>
#       </td>
#      </tr>
#     </tbody>
#    </table>
#   </div>
#   <nav aria-label="Main navigation" class="navBarMobile" id="mobileNavBar" role="navigation">
#    <ul class="topMenuList">
#     <li class="sp_menu_item">
#      <a href="/account/manage">
#       <i class="fa fa-plane">
#       </i>
#       Join FlightAware
#      </a>
#      <a class="topMenuWhyJoin" href="/about/account_types.rvt">
#       (Why Join?)
#      </a>
#     </li>
#     <li class="sp_menu_item">
#      <a class="loginLink" href="/account/login">
#       <i class="fa fa-sign-in">
#       </i>
#       Login
#      </a>
#     </li>
#     <li class="noHover " id="LocaleTopBoxItem">
#      <div id="LocaleTopBox">
#       <form action="http://flightaware.com/account/locale_switch.rvt" method="get" style="display: inline;">
#        <select class="localePicker" name="locale" onchange="this.form.submit();">
#         <option value="ar_SA">
#          العربية
#         </option>
#         <option value="cs_CZ">
#          Čeština
#         </option>
#         <option value="de_DE">
#          Deutsch
#         </option>
#         <option value="en_AU">
#          English (Australia)
#         </option>
#         <option value="en_CA">
#          English (Canada)
#         </option>
#         <option value="en_GB">
#          English (UK)
#         </option>
#         <option selected="selected" value="en_US">
#          English (USA)
#         </option>
#         <option value="es_ES">
#          Español (España)
#         </option>
#         <option value="es_MX">
#          Español
#         </option>
#         <option value="fi_FI">
#          Suomi
#         </option>
#         <option value="fr_CA">
#          Français (Canada)
#         </option>
#         <option value="fr_FR">
#          Français (France)
#         </option>
#         <option value="he_IL">
#          עִבְרִית
#         </option>
#         <option value="hi_IN">
#          हिन्दी
#         </option>
#         <option value="hr_HR">
#          Hrvatski
#         </option>
#         <option value="it_IT">
#          Italiano
#         </option>
#         <option value="ja_JP">
#          日本語
#         </option>
#         <option value="ko_KR">
#          한국어
#         </option>
#         <option value="pl_PL">
#          Polski
#         </option>
#         <option value="pt_BR">
#          Português (Brasil)
#         </option>
#         <option value="pt_PT">
#          Português (Portugal)
#         </option>
#         <option value="ru_RU">
#          Русский
#         </option>
#         <option value="tr_TR">
#          Türkçe
#         </option>
#         <option value="zh_CN">
#          中文(简体)
#         </option>
#         <option value="zh_HK">
#          中文(香港)
#         </option>
#         <option value="zh_TW">
#          中文(台灣)
#         </option>
#        </select>
#       </form>
#       <a href="http://flightaware.com/account/locale_switch.rvt?locale=en_US">
#        <img alt="US Flag" height="11" src="http://e1.flightcdn.com/images/countries/US.png" title="Switch to US FlightAware" width="16"/>
#       </a>
#      </div>
#     </li>
#    </ul>
#    <ul id="listMenuRootMobile" role="menubar">
#     <li aria-haspopup="true" class="menu_item" data-id="10" role="menuitem">
#      <a href="/live/">
#       Live Flight Tracking
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_live_trackingMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/findflight/">
#         Flight Finder
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/cancelled/">
#         Cancellations
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/airport/delays/">
#         Airport Delays
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/miserymap/">
#         MiseryMap
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/fleet/">
#         Browse by Operator
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/resources/airport/browse/">
#         Browse by Airport
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/aircrafttype/">
#         Browse by Aircraft Type
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/airport/random">
#         Random Airport
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/live/flight/random">
#         Random Flight
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/mobile">
#         Mobile Flight Tracker Apps
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/statistics/ifr-route/">
#         IFR Route Analyzer
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/resources/weather_maps/">
#         Weather
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/resources/emetar/">
#         E-metar
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="20" role="menuitem">
#      <a href="/commercial/">
#       Products
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_commercial_servicesMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/premium/">
#         Premium Accounts
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/advertising/">
#         Advertising
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/flightxml/">
#         FlightXML - Flight Status / Flight Tracking API
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/data/adsb/">
#         Firehose - Worldwide ADS-B Data Feed
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/data/surface_movement/">
#         Airport Surface Movement Data Feed
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/aireon/">
#         Global Space-Based ADS-B
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/data/">
#         Live Data Feeds
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/global/">
#         FlightAware Global
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/tv/">
#         FlightAware TV
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/customreports/">
#         Custom Reports
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/commercial/fbotoolbox">
#         FBO ToolBox
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="30" role="menuitem">
#      <a href="/adsb/">
#       ADS-B
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_adsbMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/stats">
#         Statistics
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/coverage">
#         Coverage Map
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/piaware/build">
#         Build a PiAware ADS-B Receiver
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/flightfeeder">
#         FlightFeeder ADS-B Receiver
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/adsb/faq">
#         FAQs
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/aireon/">
#         Global Space-Based ADS-B
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="40" role="menuitem">
#      <a href="/photos/">
#       Photos
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_photosMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/">
#         Popular Photos
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/browse/newest">
#         Newest Photos
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/ranked/cume">
#         Highest Ranked
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/staffpicks/cume">
#         Staff Picks
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/photos/recentcomments.rvt?page=1">
#         Recent Comments
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="50" role="menuitem">
#      <a href="/squawks/">
#       Squawks
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_squawksMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/squawks/browse/general/recently/popular">
#         Current Squawks
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/squawks/browse/general/24_hours/new">
#         New Squawks
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/squawks/">
#         Popular Squawks
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="60" role="menuitem">
#      <a href="https://discussions.flightaware.com">
#       Discussions
#      </a>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="80" role="menuitem">
#      <a href="/about/">
#       About
#      </a>
#      <ul aria-hidden="true" class="submenu" id="nav_menu_about_flightawareMobile" role="menu">
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/">
#         Overview
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/executives/">
#         Executive Profiles
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/history.rvt">
#         History
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/account_types.rvt">
#         Account Types
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/faq">
#         FAQs
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/merchandise/">
#         Company Store
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/about/careers/">
#         Careers
#        </a>
#       </li>
#       <li class="submenu_item" role="menuitem" tabindex="-1">
#        <a href="/news/">
#         Newsroom
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li aria-haspopup="true" class="menu_item" data-id="90" role="menuitem">
#      <a href="/about/contact/">
#       Contact
#      </a>
#     </li>
#     <li class="socialShare">
#      <div class="socialContainer">
#       <a class="facebook ss-icon" href="https://www.facebook.com/FlightAware">
#        
#       </a>
#       <ul class="social_submenu">
#        <li class="social_submenu_item">
#         <a class="share-button facebook-button" href="https://facebook.com/sharer.php?u=http://flightaware.com/live/flight/AAL321/history/20170823/0130Z/KLGA/KORD" target="_blank">
#          <i class="fa fa-facebook-official">
#          </i>
#          <span class="share-text">
#           Like
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="socialContainer">
#       <a class="twitter ss-icon" href="https://twitter.com/flightaware">
#        
#       </a>
#       <ul class="social_submenu">
#        <li class="social_submenu_item">
#         <a class="share-button tweet-button" href="https://twitter.com/intent/tweet?url=http://flightaware.com/live/flight/AAL321/history/20170823/0130Z/KLGA/KORD&amp;via=FlightAware" target="_blank">
#          <i class="fa fa-twitter">
#          </i>
#          <span class="share-text">
#           Tweet
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </li>
#    </ul>
#   </nav>
#   <div id="slideOutPanel">
#    <header id="topWrapper" role="banner">
#     <div class="topMenuBarWrapper">
#      <nav class="topMenuBar">
#       <ul class="topMenuList">
#        <li class="sp_menu_item">
#         <a href="/account/manage">
#          <i class="fa fa-plane">
#          </i>
#          Join FlightAware
#         </a>
#         <a class="topMenuWhyJoin" href="/about/account_types.rvt">
#          (Why Join?)
#         </a>
#        </li>
#        <li class="sp_menu_item">
#         <a class="loginLink" href="/account/login">
#          <i class="fa fa-sign-in">
#          </i>
#          Login
#         </a>
#        </li>
#        <li class="noHover " id="LocaleTopBoxItem">
#         <div id="LocaleTopBox">
#          <form action="http://flightaware.com/account/locale_switch.rvt" method="get" style="display: inline;">
#           <select class="localePicker" name="locale" onchange="this.form.submit();">
#            <option value="ar_SA">
#             العربية
#            </option>
#            <option value="cs_CZ">
#             Čeština
#            </option>
#            <option value="de_DE">
#             Deutsch
#            </option>
#            <option value="en_AU">
#             English (Australia)
#            </option>
#            <option value="en_CA">
#             English (Canada)
#            </option>
#            <option value="en_GB">
#             English (UK)
#            </option>
#            <option selected="selected" value="en_US">
#             English (USA)
#            </option>
#            <option value="es_ES">
#             Español (España)
#            </option>
#            <option value="es_MX">
#             Español
#            </option>
#            <option value="fi_FI">
#             Suomi
#            </option>
#            <option value="fr_CA">
#             Français (Canada)
#            </option>
#            <option value="fr_FR">
#             Français (France)
#            </option>
#            <option value="he_IL">
#             עִבְרִית
#            </option>
#            <option value="hi_IN">
#             हिन्दी
#            </option>
#            <option value="hr_HR">
#             Hrvatski
#            </option>
#            <option value="it_IT">
#             Italiano
#            </option>
#            <option value="ja_JP">
#             日本語
#            </option>
#            <option value="ko_KR">
#             한국어
#            </option>
#            <option value="pl_PL">
#             Polski
#            </option>
#            <option value="pt_BR">
#             Português (Brasil)
#            </option>
#            <option value="pt_PT">
#             Português (Portugal)
#            </option>
#            <option value="ru_RU">
#             Русский
#            </option>
#            <option value="tr_TR">
#             Türkçe
#            </option>
#            <option value="zh_CN">
#             中文(简体)
#            </option>
#            <option value="zh_HK">
#             中文(香港)
#            </option>
#            <option value="zh_TW">
#             中文(台灣)
#            </option>
#           </select>
#          </form>
#          <a href="http://flightaware.com/account/locale_switch.rvt?locale=en_US">
#           <img alt="US Flag" height="11" src="http://e1.flightcdn.com/images/countries/US.png" title="Switch to US FlightAware" width="16"/>
#          </a>
#         </div>
#        </li>
#        <li class="fadate-clock noHover" id="headerClock">
#         <span title="EDT">
#          02:03PM EDT
#         </span>
#        </li>
#       </ul>
#      </nav>
#     </div>
#     <div id="topContent">
#      <div class="menuIcon">
#       <i class="fa fa-bars">
#       </i>
#      </div>
#      <div class="logoLeft float_left">
#       <a href="/">
#        <img alt="FlightAware" class="faLogo " src="http://e1.flightcdn.com/images/fa_logo_white.png"/>
#       </a>
#      </div>
#      <div class="headerTrack" id="headerSearchForm">
#       <div class="flightSearchForm">
#        <div class="searchToggle text_align_right">
#         <div class="search_in">
#          <span class="search_in_content">
#           All
#          </span>
#          <select class="trackSelect">
#           <option value="omniSearch">
#            All
#           </option>
#           <option value="routeSearch">
#            Route
#           </option>
#           <option value="airlineSearch">
#            Airline flight
#           </option>
#           <option value="privateSearch">
#            Private flight (tail #)
#           </option>
#           <option value="airportSearch">
#            Airport
#           </option>
#          </select>
#         </div>
#        </div>
#        <div class="searchOption active" data-fa-search-type="omniSearch" id="omniSearch">
#         <div class="fa_omnisearch_container">
#          <form action="//flightaware.com/ajax/ignoreall/omnisearch/disambiguation.rvt" id="omnisearch_form" method="get">
#           <input name="searchterm" type="hidden" value=""/>
#           <input name="token" type="hidden" value=""/>
#           <input data-alias="flightaware.com" data-ambiguous="More results for %1 ..." data-placeholder="   Search for flight, tail, airport, or city" data-recent="Recent Searches" data-searching="Searching..." data-server="e1.flightcdn.com" data-startsearch="Please begin searching to receive suggestions" data-version="43" id="omni_headerSearchForm" tabindex="1" type="hidden"/>
#           <div class="omnisearch_loading" style="display:none;">
#            <i class="fa fa-spinner fa-pulse">
#            </i>
#           </div>
#          </form>
#         </div>
#        </div>
#        <div class="searchOption routeSearch hide text_align_left" data-fa-search-type="routeSearch">
#         <form action="/live/findflight">
#          <div class="trackInputContainer">
#           <div class="trackInput">
#            <input aria-label="Origin" class="trackRouteOrigin" name="origin" placeholder="Origin (e.g. KJFK)" tabindex="1" title="Origin (e.g. KJFK)" type="text"/>
#           </div>
#          </div>
#          <div class="route_swap">
#           <div class="header_swap">
#            <img alt="Swap" src="http://e1.flightcdn.com/images/home_main/swap_icon.png"/>
#           </div>
#          </div>
#          <div class="trackInputContainer">
#           <div class="trackInput">
#            <input aria-label="Destination " class="trackRouteDestination" name="destination" placeholder="Destination  (e.g. KLAX)" tabindex="2" title="Destination  (e.g. KLAX)" type="text"/>
#           </div>
#          </div>
#          <input hidefocus="true" style="display: none;" type="submit"/>
#         </form>
#        </div>
#        <div class="searchOption multiple hide text_align_left" data-fa-search-type="airlineSearch">
#         <form action="/live/form.rvt" class="airlineSearch">
#          <div class="trackInputContainer airlineName ">
#           <div class="trackInput">
#            <input aria-label="Airline (e.g. United)" class="trackAirlineName" id="airline_name" name="q" placeholder="Airline (e.g. United)" tabindex="2" title="Airline (e.g. United)" type="text" value="American Airlines  - AAL"/>
#           </div>
#          </div>
#          <div class="trackInputContainer flightNumber ">
#           <div class="trackInput">
#            <input aria-label="Flight # (e.g. 450)" class="trackAirlineNumber" id="ident_suffix" name="ident_suffix" placeholder="Flight # (e.g. 450)" tabindex="3" title="Flight # (e.g. 450)" type="text" value="321"/>
#           </div>
#          </div>
#          <input id="ident_prefix" name="ident_prefix" type="hidden"/>
#          <input hidefocus="true" style="display: none;" type="submit"/>
#          <span class="fa fa-times-circle-o" id="airlineSearchCancel">
#          </span>
#         </form>
#        </div>
#        <form action="/live/form.rvt" class="searchOption hide text_align_left" data-fa-search-type="privateSearch" id="privateSearch">
#         <div class="trackInput">
#          <input aria-label="Flight/Tail# (e.g. N123AB)" class="trackTail" name="ident" placeholder="Flight/Tail# (e.g. N123AB)" tabindex="4" title="Flight/Tail# (e.g. N123AB)" type="text" value=""/>
#         </div>
#        </form>
#        <form action="/live/form.rvt" class="searchOption multiple hide text_align_left" data-fa-search-type="airportSearch" id="airportSearch">
#         <div class="trackInput">
#          <input aria-label="Airport Code (e.g. KJFK)" class="trackAirportCode" id="airport" name="airport" placeholder="Airport Code (e.g. KJFK)" tabindex="5" title="Airport Code (e.g. KJFK)" type="text" value=""/>
#         </div>
#         <div class="trackInput">
#          <input aria-label="Airport City (e.g. New York)" class="trackAirportCity" id="airport_name_or_city" name="airport_name_or_city" placeholder="Airport City (e.g. New York)" tabindex="6" title="Airport City (e.g. New York)" type="text"/>
#         </div>
#         <input hidefocus="true" style="display: none;" type="submit"/>
#        </form>
#        <div class="trackSubmit">
#         <button class="orange_button" tabindex="7" type="submit">
#          Track
#         </button>
#        </div>
#       </div>
#      </div>
#      <nav aria-label="Main navigation" class="navBar" role="navigation">
#       <ul id="listMenuRoot" role="menubar">
#        <li aria-haspopup="true" class="menu_item" data-id="10" role="menuitem">
#         <a href="/live/">
#          Live Flight Tracking
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_live_tracking" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/findflight/">
#            Flight Finder
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/cancelled/">
#            Cancellations
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/airport/delays/">
#            Airport Delays
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/miserymap/">
#            MiseryMap
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/fleet/">
#            Browse by Operator
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/resources/airport/browse/">
#            Browse by Airport
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/aircrafttype/">
#            Browse by Aircraft Type
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/airport/random">
#            Random Airport
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/live/flight/random">
#            Random Flight
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/mobile">
#            Mobile Flight Tracker Apps
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/statistics/ifr-route/">
#            IFR Route Analyzer
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/resources/weather_maps/">
#            Weather
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/resources/emetar/">
#            E-metar
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="20" role="menuitem">
#         <a href="/commercial/">
#          Products
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_commercial_services" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/premium/">
#            Premium Accounts
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/advertising/">
#            Advertising
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/flightxml/">
#            FlightXML - Flight Status / Flight Tracking API
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/data/adsb/">
#            Firehose - Worldwide ADS-B Data Feed
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/data/surface_movement/">
#            Airport Surface Movement Data Feed
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/aireon/">
#            Global Space-Based ADS-B
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/data/">
#            Live Data Feeds
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/global/">
#            FlightAware Global
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/tv/">
#            FlightAware TV
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/customreports/">
#            Custom Reports
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/commercial/fbotoolbox">
#            FBO ToolBox
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="30" role="menuitem">
#         <a href="/adsb/">
#          ADS-B
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_adsb" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/stats">
#            Statistics
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/coverage">
#            Coverage Map
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/piaware/build">
#            Build a PiAware ADS-B Receiver
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/flightfeeder">
#            FlightFeeder ADS-B Receiver
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/adsb/faq">
#            FAQs
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/aireon/">
#            Global Space-Based ADS-B
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="40" role="menuitem">
#         <a href="/photos/">
#          Photos
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_photos" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/">
#            Popular Photos
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/browse/newest">
#            Newest Photos
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/ranked/cume">
#            Highest Ranked
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/staffpicks/cume">
#            Staff Picks
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/photos/recentcomments.rvt?page=1">
#            Recent Comments
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="50" role="menuitem">
#         <a href="/squawks/">
#          Squawks
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_squawks" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/squawks/browse/general/recently/popular">
#            Current Squawks
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/squawks/browse/general/24_hours/new">
#            New Squawks
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/squawks/">
#            Popular Squawks
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="60" role="menuitem">
#         <a href="https://discussions.flightaware.com">
#          Discussions
#         </a>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="80" role="menuitem">
#         <a href="/about/">
#          About
#         </a>
#         <ul aria-hidden="true" class="submenu" id="nav_menu_about_flightaware" role="menu">
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/">
#            Overview
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/executives/">
#            Executive Profiles
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/history.rvt">
#            History
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/account_types.rvt">
#            Account Types
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/faq">
#            FAQs
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/merchandise/">
#            Company Store
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/about/careers/">
#            Careers
#           </a>
#          </li>
#          <li class="submenu_item" role="menuitem" tabindex="-1">
#           <a href="/news/">
#            Newsroom
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li aria-haspopup="true" class="menu_item" data-id="90" role="menuitem">
#         <a href="/about/contact/">
#          Contact
#         </a>
#        </li>
#        <li class="socialShare">
#         <div class="socialContainer">
#          <a class="facebook ss-icon" href="https://www.facebook.com/FlightAware">
#           
#          </a>
#          <ul class="social_submenu">
#           <li class="social_submenu_item">
#            <a class="share-button facebook-button" href="https://facebook.com/sharer.php?u=http://flightaware.com/live/flight/AAL321/history/20170823/0130Z/KLGA/KORD" target="_blank">
#             <i class="fa fa-facebook-official">
#             </i>
#             <span class="share-text">
#              Like
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="socialContainer">
#          <a class="twitter ss-icon" href="https://twitter.com/flightaware">
#           
#          </a>
#          <ul class="social_submenu">
#           <li class="social_submenu_item">
#            <a class="share-button tweet-button" href="https://twitter.com/intent/tweet?url=http://flightaware.com/live/flight/AAL321/history/20170823/0130Z/KLGA/KORD&amp;via=FlightAware" target="_blank">
#             <i class="fa fa-twitter">
#             </i>
#             <span class="share-text">
#              Tweet
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </header>
#    <div class="pageContainer">
#     <script type="text/javascript">
#      $(function(){new FlightPage();});
#     </script>
#     <div class="flightPageAd flightPageNewAdUnit" data-set="flightPageAds">
#     </div>
#     <div class="flightPageContainer">
#      <div class="flightPageBlockedData" data-template="live/flight/blocked">
#      </div>
#      <div class="flightPageUnknownData" data-template="live/flight/unknown">
#      </div>
#      <div class="flightPageSummaryMap">
#       <div data-template="live/flight/summary">
#       </div>
#       <div data-template="live/flight/summaryLinks">
#       </div>
#       <div data-template="live/flight/airportDelays">
#       </div>
#       <div data-template="live/flight/adhoc">
#       </div>
#       <div class="flightPageMapContainer" id="flightPageTourStepMap">
#        <div id="flightPageInteractiveMap" style="width:100%; height:600px;">
#        </div>
#        <div class="flightPageStaticMapContainer" data-server="flightxml.flightaware.com">
#         <div class="flightPageStaticMap" data-disable-refresh="true" data-template="live/flight/staticMap">
#         </div>
#         <div class="flightPageNotificationContainer" data-template="live/flight/notification">
#         </div>
#        </div>
#       </div>
#       <div class="flightPageSummaryMapDetails">
#        <div data-template="live/flight/airline">
#        </div>
#        <div data-template="live/flight/data">
#        </div>
#       </div>
#       <div class="flightPageActivityLogTop" data-set="flightPageRemarksActivityLog">
#        <div class="remarksAndActivityLog" data-template="live/flight/positionOnly" id="flightPagePositionOnly">
#        </div>
#        <div class="flightPageActivityLog remarksAndActivityLog" data-template="live/flight/log" id="flightPageActivityLog">
#        </div>
#       </div>
#      </div>
#      <div class="flightPageDetails">
#       <div class="flightPageCondensedSummary" data-template="live/flight/summary">
#       </div>
#       <div class="flightPageSponsorshipAd viewableAdHome" data-set="flightPageAds">
#        <div class="flightPageAdUnit">
#         <script>
#          var googletag = googletag || {};
# 			googletag.cmd = googletag.cmd || [];
# 			(function() {
# 				var gads = document.createElement('script');
# 				gads.async = true;
# 				gads.type = 'text/javascript';
# 				var useSSL = 'https:' == document.location.protocol;
# 				gads.src = (useSSL ? 'https:' : 'http:') +
# 				'//www.googletagservices.com/tag/js/gpt.js';
# 				var node = document.getElementsByTagName('script')[0];
# 				node.parentNode.insertBefore(gads, node);
# 			})();
# 			if (typeof googletag.enableSingleRequest === 'function') {
# 				googletag.cmd.push(function() { googletag.enableSingleRequest(); });
# 			}
# 			var displayGoogleAd = function(id) { googletag.display(id); }
#         </script>
#         <script>
#          googletag.cmd.push(function() {
# 					var mapping = googletag.sizeMapping().addSize([0,0], [[320,50]]).addSize([768,0], [[300,250]]).build();
# 					googletag.defineSlot('/6254/flight.main/live/flight/atf', [[300,250]], 'FA_ads_764228').defineSizeMapping(mapping).addService(googletag.pubads()).setTargeting('aircraft_make', 'Boeing').setTargeting('aircraft_model', '737-800').setTargeting('aircraft_type', 'B738').setTargeting('dcove', 'd').setTargeting('destination', 'KORD').setTargeting('destination_IATA', 'ORD').setTargeting('destination_state', 'IL').setTargeting('engine_category', 'turbine').setTargeting('engine_type', 'twin-jet').setTargeting('filed_ete', '2h3h').setTargeting('flightstatus', 'cancelled').setTargeting('ident', 'AAL321').setTargeting('lang', 'en').setTargeting('lifeguard', '0').setTargeting('locale', 'en_US').setTargeting('origin', 'KLGA').setTargeting('origin_IATA', 'LGA').setTargeting('origin_state', 'NY').setTargeting('physclass', 'J').setTargeting('prefix', 'AAL').setTargeting('type', 'airline').setTargeting('unitName', 'flight').setTargeting('userGen', 'f').setTargeting('userclass', '');
# 					googletag.pubads().setCentering(true);
# 					googletag.enableServices();
# 				});
#         </script>
#         <div class="fa-google-ad" id="FA_ads_764228" style="min-height:250px;">
#         </div>
#        </div>
#       </div>
#       <div class="flightPageNotificationContainer" data-template="live/flight/notification">
#       </div>
#       <div data-template="live/flight/airportDelays">
#       </div>
#       <div data-template="live/flight/details">
#       </div>
#       <div data-template="live/flight/airline">
#       </div>
#       <div data-template="live/flight/data">
#       </div>
#       <div data-disable-refresh="true" data-template="live/flight/thumbnailCarousel">
#       </div>
#       <div class="flightPageYieldMoAd" data-set="flightPageAdsBottom">
#       </div>
#       <div class="flightPageRemarks remarksAndActivityLog" data-template="live/flight/remarks">
#       </div>
#       <div class="flightPageReportInaccuraciesRight" data-set="flightPageReportInaccuracies">
#       </div>
#       <div class="flightPageSponsorshipAd">
#       </div>
#      </div>
#      <div class="flightPageActivityLogBottom" data-set="flightPageRemarksActivityLog">
#      </div>
#      <div class="flightPageReportInaccuraciesBottom" data-set="flightPageReportInaccuracies">
#       <div class="flightPageReportInaccuracies" data-disable-refresh="true" data-template="live/flight/reportInaccuracies">
#       </div>
#      </div>
#      <div data-disable-refresh="true" data-template="live/flight/modal/notifications">
#      </div>
#      <div data-disable-refresh="true" data-template="live/flight/modal/settings">
#      </div>
#      <div data-disable-refresh="true" data-template="live/flight/modal/remark">
#      </div>
#     </div>
#     <div class="flightPageAdBottom flightPageNewAdUnit" data-set="flightPageAdsBottom">
#      <div class="flightPageAdUnit">
#       <script>
# ...
#   </script>
#   <script data-tpl="live/flight/reportInaccuracies" type="text/javascript">
#    !function(){var a=Handlebars.template,e=Handlebars.templates=Handlebars.templates||{};e.reportInaccuracies=a({1:function(a,e,t,i,l){return'<p>Please provide an email address where we can contact you for more information:</p>\n<input type="email" name="email" id="flightPageReportEmail" class="flightPageReportEmail">\n'},compiler:[7,">= 4.0.0"],main:function(a,e,t,i,l){var n,r=null!=e?e:{},o=t.helperMissing,s=a.escapeExpression;return'<!-- Report inaccuracies -->\n\n<h3 id="flightPageReportPanel" class="flightPageDataTableHeading" data-collapsible="true"><i class="fa fa-plus-square" aria-hidden="true"></i> <span>'+s((t.mc||e&&e.mc||o).call(r,"FP_Report_Inaccuracies","Report inaccuracies on this page",{name:"mc",hash:{},data:l}))+'</span></h3>\n\n\n<div class="flightPageReportInaccuraciesForm flightPageDataTable" id="flightPageReportInaccuraciesForm">\n<form id="reportInaccuracies" method="post" action="'+s(a.lambda(null!=(n=null!=e?e.links:e)?n.reportInaccuracies:n,e))+'" enctype="multipart/form-data">\n<input type="hidden" name="json_report" id="json_report" value="">\n<input type="radio" name="errorRadio" id="times" value="times">\n<input type="radio" name="errorRadio" id="airports" value="airports">\n<input type="radio" name="errorRadio" id="aircraft_type" value="aircraft_type">\n<input type="radio" name="errorRadio" id="path" value="path">\n<input type="radio" name="errorRadio" id="not_cancelled" value="not_cancelled">\n<input type="radio" name="errorRadio" id="cancelled" value="cancelled">\n<input type="radio" name="errorRadio" id="other" value="other">\n<h3 class="flightPageDataTableHeading">Please Identify The Issue</h3>\n<div class="flightPageDataTable">\n<div class="flightPageDataRow">\n<label for="times" class="flightPageReportType">Inaccurate arrival/departure time</label>\n</div>\n<div class="flightPageDataRow">\n<label for="airports" class="flightPageReportType">Inaccurate origin/destination airport</label>\n</div>\n<div class="flightPageDataRow">\n<label for="aircraft_type" class="flightPageReportType">Inaccurate aircraft type</label>\n</div>\n<div class="flightPageDataRow">\n<label for="path" class="flightPageReportType">Inaccurate depicted flight path on map</label>\n</div>\n<div class="flightPageDataRow">\n<label for="not_cancelled" class="flightPageReportType">Flight was shown as canceled, but actually operated</label>\n</div>\n<div class="flightPageDataRow">\n<label for="cancelled" class="flightPageReportType">Flight should have been shown as canceled</label>\n</div>\n<div class="flightPageDataRow">\n<label for="other" class="flightPageReportType">Other (please explain below)</label>\n</div>\n</div>\n<div class="flightPageReportDetails">\n<div class="flightPageReportComments">\n<p>Please provide any additional clarifying information:</p>\n<textarea class="flightPageReportTextarea" id="flightPageReportTextarea" name="clarification"></textarea>\n</div>\n<div class="flightPageReportEmailAndFile">\n'+(null!=(n=t.unless.call(r,(t.isLoggedIn||e&&e.isLoggedIn||o).call(r,{name:"isLoggedIn",hash:{},data:l}),{name:"unless",hash:{},fn:a.program(1,l,0),inverse:a.noop,data:l}))?n:"")+'<p>If possible, upload a screenshot or image demonstrating the issue: <input type="file" name="media" class="flightPageReportFile" id="flightPageReportFile"></p>\n\n\n<p class="flightPageReportButton"><a href="#" class="flightPageButton" data-action="reportInaccuracies"><span>Submit Report</span></a></p>\n</div>\n</div>\n</form>\n</div>'},useData:!0})}();
#   </script>
#   <script data-tpl="live/flight/positionOnly" type="text/javascript">
#    !function(){var e=Handlebars.template,n=Handlebars.templates=Handlebars.templates||{};n.positionOnly=e({1:function(e,n,a,i,s){var l,t=null!=n?n:{};return null!=(l=a.if.call(t,(a.suggestAdhoc||n&&n.suggestAdhoc||a.helperMissing).call(t,{name:"suggestAdhoc",hash:{},data:s}),{name:"if",hash:{},fn:e.program(2,s,0),inverse:e.noop,data:s}))?l:""},2:function(e,n,a,i,s){var l,t=null!=n?n:{},r=a.helperMissing;return'<div id="suggestAdhocNotice" class="flightPageAdhocNotice">\n<p><strong>'+e.escapeExpression((a.mc||n&&n.mc||r).call(t,"FP_Hidden_Flights_Summary","There are flights hidden from view because they were not matched with a flight plan.",{name:"mc",hash:{},data:s}))+"</strong></p>\n"+(null!=(l=a.if.call(t,(a.isActiveUser||n&&n.isActiveUser||r).call(t,{name:"isActiveUser",hash:{},data:s}),{name:"if",hash:{},fn:e.program(3,s,0),inverse:e.program(5,s,0),data:s}))?l:"")+"</div>\n"},3:function(e,n,a,i,s){return'<a id="showAdhoc" href="javascript:void(0)">'+e.escapeExpression((a.mc||n&&n.mc||a.helperMissing).call(null!=n?n:{},"FP_Hidden_Flights_View","View all hidden position-only flights",{name:"mc",hash:{},data:s}))+"</a>\n"},5:function(e,n,a,i,s){var l,t=null!=n?n:{};return null!=(l=a.if.call(t,(a.isLoggedIn||n&&n.isLoggedIn||a.helperMissing).call(t,{name:"isLoggedIn",hash:{},data:s}),{name:"if",hash:{},fn:e.program(6,s,0),inverse:e.program(8,s,0),data:s}))?l:""},6:function(e,n,a,i,s){return"<p><strong>"+e.escapeExpression((a.mc||n&&n.mc||a.helperMissing).call(null!=n?n:{},"FP_Hidden_Flights_Act_Account","%1Activate%2 your account to show position-only flights.",'<a href="/account/act">',"</a>",{name:"mc",hash:{},data:s}))+"</strong></p>\n"},8:function(e,n,a,i,s){var l,t=null!=n?n:{},r=a.helperMissing;return'<a id="redirectAdhoc" href="'+(null!=(l=(a.refererLink||n&&n.refererLink||r).call(t,"/account/login",{name:"refererLink",hash:{},data:s}))?l:"")+'">'+e.escapeExpression((a.mc||n&&n.mc||r).call(t,"FP_Hidden_Flights_Login","Login or create an account to view hidden flights",{name:"mc",hash:{},data:s}))+"</a>\n"},compiler:[7,">= 4.0.0"],main:function(e,n,a,i,s){var l;return"<!-- Notification to enable position-only flights -->\n"+(null!=(l=a.unless.call(null!=n?n:{},null!=n?n.adhoc:n,{name:"unless",hash:{},fn:e.program(1,s,0),inverse:e.noop,data:s}))?l:"")},useData:!0})}();
#   </script>
#   <script data-tpl="live/flight/notificationButton_partial" type="text/javascript">
#    !function(){var a=Handlebars.template;Handlebars.templates=Handlebars.templates||{};Handlebars.partials.notificationButton_partial=a({1:function(a,n,t,i,l){var o,e=null!=n?n:{},s=t.helperMissing,c="function",r=a.escapeExpression;return'<a href="'+r((o=null!=(o=t.notificationUrl||(null!=n?n.notificationUrl:n))?o:s,typeof o===c?o.call(e,{name:"notificationUrl",hash:{},data:l}):o))+'" class="'+r((o=null!=(o=t.notificationClasses||(null!=n?n.notificationClasses:n))?o:s,typeof o===c?o.call(e,{name:"notificationClasses",hash:{},data:l}):o))+'">'+r((o=null!=(o=t.notificationContent||(null!=n?n.notificationContent:n))?o:s,typeof o===c?o.call(e,{name:"notificationContent",hash:{},data:l}):o))+"</a>\n"},3:function(a,n,t,i,l){var o,e=null!=n?n:{};return null!=(o=t.if.call(e,(t.hasArrived||n&&n.hasArrived||t.helperMissing).call(e,{name:"hasArrived",hash:{},data:l}),{name:"if",hash:{},fn:a.program(4,l,0),inverse:a.program(6,l,0),data:l}))?o:""},4:function(a,n,t,i,l){var o,e=null!=n?n:{},s=t.helperMissing,c="function",r=a.escapeExpression;return'<a href="'+r((o=null!=(o=t.notificationUrl||(null!=n?n.notificationUrl:n))?o:s,typeof o===c?o.call(e,{name:"notificationUrl",hash:{},data:l}):o))+'" class="'+r((o=null!=(o=t.notificationClasses||(null!=n?n.notificationClasses:n))?o:s,typeof o===c?o.call(e,{name:"notificationClasses",hash:{},data:l}):o))+'" data-reveal-id="flightPageNotificationModal" title="'+r((t.mc||n&&n.mc||s).call(e,"FP_Status_Updates_Not_Available","Status updates are not available for historical flights.",{name:"mc",hash:{},data:l}))+'">'+r((o=null!=(o=t.notificationContent||(null!=n?n.notificationContent:n))?o:s,typeof o===c?o.call(e,{name:"notificationContent",hash:{},data:l}):o))+"</a>\n"},6:function(a,n,t,i,l){var o,e=null!=n?n:{},s=t.helperMissing,c="function",r=a.escapeExpression;return'<a href="'+r((o=null!=(o=t.notificationUrl||(null!=n?n.notificationUrl:n))?o:s,typeof o===c?o.call(e,{name:"notificationUrl",hash:{},data:l}):o))+'" class="'+r((o=null!=(o=t.notificationClasses||(null!=n?n.notificationClasses:n))?o:s,typeof o===c?o.call(e,{name:"notificationClasses",hash:{},data:l}):o))+'" data-reveal-id="flightPageNotificationModal">'+r((o=null!=(o=t.notificationContent||(null!=n?n.notificationContent:n))?o:s,typeof o===c?o.call(e,{name:"notificationContent",hash:{},data:l}):o))+"</a>\n"},compiler:[7,">= 4.0.0"],main:function(a,n,t,i,l){var o;return null!=(o=t.if.call(null!=n?n:{},null!=n?n.ga:n,{name:"if",hash:{},fn:a.program(1,l,0),inverse:a.program(3,l,0),data:l}))?o:""},useData:!0})}();
#   </script>
#   <script>
#    $(window).one('createMap.flightPageInteractiveMap', function(){
# 				FAMap_1_promise = FAMap.factory('flightPageInteractiveMap', function(){ return FAMap.Util.ConfigPresets.getFullConfig('flight', {"groups":["anonUsers","earthcastUsers","aviationCharts"],"FAS":false,"defaultExtent":[-13854058.502631625161,3130860.6785608194768,-8022830.4888120982796,6457400.1495316904038],"analytics":"Google","fullsizeMapUrl":"/live/flight/map/AAL321/history/20170823/0130Z/KLGA/KORD"}) });
# 			});
#   </script>
#   <script type="text/javascript">
#    $(function() {
# 			$("body").append("<iframe src='/ajax/ignoreall/hash2.rvt?k=travel,flight,flight to New York,flight from Chicago,American Airlines Inc.' style='display: none;'></iframe>");
# 		});
#   </script>
#   <script>
#    var trackpollBootstrap = {"version":"2.0","summary":false,"flights":{"AAL321-1503206732-airline-0334":{"activityLog":{"flights":[{"origin":{"TZ":":America/New_York","isValidAirportCode":true,"altIdent":null,"iata":"LGA","friendlyName":"LaGuardia","friendlyLocation":"New York, NY","coord":[-73.8726,40.7773],"icao":"KLGA","gate":"D8","terminal":"B","delays":null},"destination":{"TZ":":America/Chicago","isValidAirportCode":true,"altIdent":null,"iata":"ORD","friendlyName":"Chicago O'Hare Intl","friendlyLocation":"Chicago, IL","coord":[-87.9080,41.9773],"icao":"KORD","gate":"K16","terminal":"3","delays":null},"aircraftType":"B738","aircraftTypeFriendly":"Boeing 737-800 (twin-jet)","flightId":"AAL321-1506835565-airline-0272","takeoffTimes":{"scheduled":1507080600,"estimated":1507081200,"actual":null},"landingTimes":{"scheduled":1507088940,"estimated":1507089540,"actual":null},"gateDepartureTimes":{"scheduled":1507080600,"estimated":null,"actual":null},"gateArrivalTimes":{"scheduled":1507090140,"estimated":null,"actual":null},"ga":false,"cancelled":false,"resultUnknown":false,"diverted":false,"adhoc":false,"fruOverride":false,"timestamp":null,"permaLink":"/live/flight/AAL321/history/20171004/0130Z/KLGA/KORD"},{"origin":{"TZ":":America/New_York","isValidAirportCode":true,"altIdent":null,"iata":"LGA","friendlyName":"LaGuardia","friendlyLocation":"New York, NY","coord":[-73.8726,40.7773],"icao":"KLGA","gate":"D8","terminal":"B","delays":null},"destination":{"TZ":":America/Chicago","isValidAirportCode":true,"altIdent":null,"iata":"ORD","friendlyName":"Chicago O'Hare Intl","friendlyLocation":"Chicago, IL","coord":[-87.9080,41.9773],"icao":"KORD","gate":"K8","terminal":"3","delays":null},"aircraftType":"B738","aircraftTypeFriendly":"Boeing 737-800 (twin-jet)","flightId":"AAL321-1506749163-airline-0630","takeoffTimes":{"scheduled":1506994200,"estimated":1506994800,"actual":null},"landingTimes":{"scheduled":1507002540,"estimated":1507003140,"actual":null},"gateDepartureTimes":{"scheduled":1506994200,"estimated":null,"actual":null},"gateArrivalTimes":{"scheduled":1507003740,"estimated":null,"actual":null},"ga":false,"cancelled":false,"resultUnknown":false,"diverted":false,"adhoc":false,"fruOverride":false,"timestamp":null,"permaLink":"/live/flight/AAL321/history/20171003/0130Z/KLGA/KORD"},{"origin":{"TZ":":America/New_York","isValidAirportCode":true,"altIdent":null,"iata":"LGA","friendlyName":"LaGuardia","friendlyLocation":"New York, NY","coord":[-73.8726,40.7773],"icao":"KLGA","gate":"D8","terminal":"B","delays":null},"destination":{"TZ":":America/Chicago","isValidAirportCode":true,"altIdent":null,"iata":"ORD","friendlyName":"Chicago O'Hare Intl","friendlyLocation":"Chicago, IL","coord":[-87.9080,41.9773],"icao":"KORD","gate":"H6","terminal":"3","delays":null},"aircraftType":"B738","aircraftTypeFriendly":"Boeing 737-800 (twin-jet)","flightId":"AAL321-1506662767-airline-0030","takeoffTimes":{"scheduled":1506907800,"estimated":1506908880,"actual":1506908880},"landingTimes":{"scheduled":1506916320,"estimated":1506915300,"actual":1506915300},"gateDepartureTimes":{"scheduled":1506907800,"estimated":1506907860,"actual":1506907860},"gateArrivalTimes":{"scheduled":1506917340,"estimated":1506915600,"actual":1506915600},"ga":false,"cancelled":false,"resultUnknown":false,"diverted":false,"adhoc":false,"fruOverride":false,"timestamp":null,"permaLink":"/live/flight/AAL321/history/20171002/0130Z/KLGA/KORD"},{"origin":{"TZ":":America/New_York","isValidAirportCode":true,"altIdent":null,"iata":"LGA","friendlyName":"LaGuardia","friendlyLocation":"New York, NY","coord":[-73.8726,40.7773],"icao":"KLGA","gate":"D8","terminal":"B","delays":null},"destination":{"TZ":":America/Chicago","isValidAirportCode":true,"altIdent":null,"iata":"ORD","friendlyName":"Chicago O'Hare Intl","friendlyLocation":"Chicago, IL","coord":[-87.9080,41.9773],"icao":"KORD","gate":"H15","terminal":"3","delays":null},"aircraftType":"B738","aircraftTypeFriendly":"Boeing 737-800 (twin-jet)" ...
#   </script>
#   <script crossorigin="anonymous" src="http://e1.flightcdn.com/include/6247bc739-maps/TrackPollClient.js" type="text/javascript">
#   </script>
#   <script>
#    var trackpollGlobals = {"TOKEN":"c35ca45ecbca57cd1ea443d1c65c36426ea06630de026ffd737977e4a40a26ead614b3f2ddde9907453c214a859f7965-dd1320656957446e5ca0b3670908242458922d443cbc98e76b5f6ed15f0e6f4b2af08e78c2c6462beffc2a80a6a9a1e2-edea7d20647f0b750e085841d74af094037bca0c","INTERVAL":65,"SINGLE_FLIGHT":true,"USERTOKEN":""};
#   </script>
#   <script type="text/javascript">
#    (function(FA) { FA.headerSearch = (function() { var flightSearchForm = new FA.Modules.UI.FlightSearchForm('headerSearchForm', { 'stateSelectorClass' : '.trackSelect' , 'dashboardView' : 'toggle' } ); flightSearchForm.init();  return flightSearchForm; })(); })(FA);
#   </script>
#   <script type="text/javascript">
#    $("#headerSearchForm .flightSearchForm").append('<div class="forgot"><a href="/live/findflight/" > FORGOT the FLIGHT  NUMBER? </a></div>');
#   </script>
#   <script crossorigin="anonymous" src="http://e1.flightcdn.com/include/9fefb032d-flightpage/model.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# No matter the date passed in the URL, it spits back a page. The following determines if that page represents an actual flight or not:

# %%
def is_flight(soup):
    """Returns True if page is an actual flight, and False if not."""
    
    names = []
    for meta in soup.find_all('meta'):
        names.append(meta.get('name'))
        
    if 'airline' in names:
        return True
    else:
        return False

# %%
# arrived
is_flight(soup_arr)
# Out:
# True

# %%
# canceled
is_flight(soup_c)
# Out:
# True

# %%
# no flight on that date
is_flight(soup_nf)
# Out:
# False

# %% [markdown]
# The part that shows if a flight was canceled resides within a `div` with `class="flightPageFriendlyIdent"`, and this class name is only used once. Unfortunately, searching for that class returns nothing:

# %%
ident = soup_c.find(class_="flightPageFriendlyIdent")
print(ident)
# Out:
# None

# %% [markdown]
# This seems to work though:

# %%
def is_canceled(soup):
    return soup.text.count('cancelled') == 32

# %%
# canceled
is_canceled(soup_c)
# Out:
# True

# %%
# arrived
is_canceled(soup_arr)
# Out:
# False

# %% [markdown]
# Arrival times live within a `div` of `class="flightPageDetails"`, then in a `div` of `data-template="live/flight/details"`, and finally in the second `div` of `class="flightPageDataTable"`.

# %%
details = soup_arr.find(class_="flightPageDetails")
details.find(attrs={"data-template": "live/flight/details"})
# Out:
# <div data-template="live/flight/details"></div>

# %% [markdown]
# This one is empty, so we can't even get to the `'flightPageDataTable'` that we need. Soup is not enough...

# %% [markdown]
# #### Testing Selenium

# %%
driver = webdriver.Chrome(chromedriver)

# %%
driver.get(arrived_url)

# %% [markdown]
# Can't say I have high hopes here, but just in case...

# %%
soup1 = BeautifulSoup(driver.page_source, 'html.parser')

# %%
details1 = soup1.find(class_="flightPageDetails")
details_sub1 = details1.find(attrs={"data-template": "live/flight/details"})
details_sub1
# Out:
# <div data-template="live/flight/details"><!-- Flight details heading -->
# <h3 class="flightPageHeading">
# Flight Details
# <span class="flightPageLastUpdateTimestamp"></span></h3>
# <!-- Links -->
# <div class="flightPageLinks flightPageLinksDetails">
# <div class="halfButtonTable">
# <a class="halfButton text-center" href="/live/flight/AAL321/history/20170824/0130Z/KLGA/KORD/tracklog"><span>View track log</span></a>
# </div>
# <div class="flightPageLinksDetailsBottom">
# <a href="/live/findflight/KLGA/KORD">
# <span>
# All flights between LGA and ORD
# </span>
# </a>
# </div>
# </div>
# <!-- Flight times -->
# <!-- Departure times -->
# <h3 class="flightPageDataTableHeading">Departure Times</h3>
# <div class="flightPageDataTable">
# <!-- Table header -->
# <div class="flightPageHeaderRow">
# <div class="flightPageHeaderColumn"> </div>
# <div class="flightPageHeaderColumn">Gate Departure</div>
# <div class="flightPageHeaderColumn">Taxiing</div>
# <div class="flightPageHeaderColumn">Takeoff</div>
# </div>
# <!-- Actual / Estimated -->
# <div class="flightPageDataRow">
# <div class="flightPageTimeLabel">
# Actual
# </div>
# <div class="flightPageTimeData">
# <span>09:25PM EDT</span>
# </div>
# <div class="flightPageTimeData">
# 33 minutes
# </div>
# <div class="flightPageTimeData">
# <span>09:58PM EDT</span>
# </div>
# </div>
# <!-- Scheduled -->
# <div class="flightPageDataRow">
# <div class="flightPageTimeLabel">Scheduled</div>
# <div class="flightPageTimeData">
# <span>09:30PM EDT</span>
# </div>
# <div class="flightPageTimeData">
#
# </div>
# <div class="flightPageTimeData">
# <span>09:30PM EDT</span>
# </div>
# </div>
# <!-- Average Delay -->
# <div class="flightPageDataRow">
# <div class="flightPageTimeLabel">Average Delay</div>
# <div class="flightPageTimeData">
# Less than 10 minutes
# </div>
# <div class="flightPageTimeData"> </div>
# <div class="flightPageTimeData"> </div>
# </div>
# </div>
# <!-- Arrival times -->
# <h3 class="flightPageDataTableHeading">Arrival Times</h3>
# <div class="flightPageDataTable">
# <!-- Table header -->
# <div class="flightPageHeaderRow">
# <div class="flightPageHeaderColumn"> </div>
# <div class="flightPageHeaderColumn">Landing</div>
# <div class="flightPageHeaderColumn">Taxiing</div>
# <div class="flightPageHeaderColumn">Gate Arrival</div>
# </div>
# <!-- Actual / Estimated -->
# <div class="flightPageDataRow">
# <div class="flightPageTimeLabel">
# Actual
# </div>
# <div class="flightPageTimeData">
# <span>
# 10:56PM CDT
#
# </span>
# </div>
# <div class="flightPageTimeData">
# 5 minutes
# </div>
# <div class="flightPageTimeData">
# <span>
# 11:01PM CDT
#
# </span>
# </div>
# </div>
# <!-- Scheduled -->
# <div class="flightPageDataRow">
# <div class="flightPageTimeLabel">Scheduled</div>
# <div class="flightPageTimeData">
# <span>
# 10:25PM CDT
#
#
# </span>
# </div>
# <div class="flightPageTimeData">
#
# </div>
# <div class="flightPageTimeData">
# <span>
# 11:09PM CDT
#
# </span>
# </div>
# </div>
# <!-- Average Delay -->
# <div class="flightPageDataRow">
# <div class="flightPageTimeLabel">Average Delay</div>
# <div class="flightPageTimeData"> </div>
# <div class="flightPageTimeData"> </div>
# <div class="flightPageTimeData">
# Less than 10 minutes
# </div>
# </div>
# </div>
# <!-- Aircraft information -->
# <h3 class="flightPageDataTableHeading">Aircraft information</h3>
# <div class="flightPageDataTable">
# <!-- Tail number -->
# <!-- Registration -->
# <!-- Aircraft type -->
# <div class="flightPageDataRow">
# <div class="flightPageDataLabel">Aircraft Type</div>
# <div class="flightPageData">
# Boeing 737-800 (twin-jet) (<a href="/live/aircrafttype/B738">B738</a>)</div>
# <div class="flightPageData">
# <a class="flightPageLink" href="/photos/aircrafttype/B738">Photos</a>
# </div>
# </div>
# </div></div>

# %% [markdown]
# It works! Here are the target numbers:
# * Landing (actual) – 10:56 PM
# * Gate Arrival (actual) – 11:01 PM
# * Landing (sched) – 10:25 PM
# * Gate Arrival (sched) – 11:09 PM

# %%
for i, e in enumerate(details_sub1.find_all('span')):
    print(f"*** {i}.\n{e.text}")
# Out:
# *** 0.
#
# *** 1.
# View track log
# *** 2.
#
# All flights between LGA and ORD
#
# *** 3.
# 09:25PM EDT
# *** 4.
# 09:58PM EDT
# *** 5.
# 09:30PM EDT
# *** 6.
# 09:30PM EDT
# *** 7.
#
# 10:56PM CDT
#
#
# *** 8.
#
# 11:01PM CDT
#
#
# *** 9.
#
# 10:25PM CDT
#
#
#
# *** 10.
#
# 11:09PM CDT

# %%
# here we can get our arrival times

spans = list(details_sub.find_all('span'))

arrival_times = []

for i in range(7,11):
    arrival_times.append(spans[i].text.strip())

for time in arrival_times:
    print(time)
# Out:
# 10:56PM CDT
# 11:01PM CDT
# 10:25PM CDT
# 11:09PM CDT

# %%
search_date = datetime.strptime("20170824", "%Y%m%d").date()
search_date
# Out:
# datetime.date(2017, 8, 24)

# %%
# then convert to datetime
arrival_times_conv = map(lambda x: datetime.strptime(x, "%I:%M%p %Z").time(), arrival_times)
arrival_times_conv2 = list(map(lambda x: datetime.combine(search_date, x), arrival_times_conv))

for time in arrival_times_conv2:
    print(time)
# Out:
# 2017-08-24 22:56:00
# 2017-08-24 23:01:00
# 2017-08-24 22:25:00
# 2017-08-24 23:09:00

# %% [markdown]
# Practice function:

# %%
def get_arrival_times(search_date_string, soup):
    search_date = datetime.strptime(search_date_string, "%Y%m%d").date()
    details = soup.find(class_="flightPageDetails")
    details_sub = details.find(attrs={"data-template": "live/flight/details"})
    spans = list(details_sub.find_all('span'))
    arrival_times = []
    # debugging
    for i, e in enumerate(details_sub.find_all('span')):
        print(f"*** {i}.\n{e.text}")
        
    for i in range(7,11):
        time_str = spans[i].text.strip().split(' ')[0]
        arrival_times.append(time_str)
    at_conv = map(lambda x: datetime.strptime(x, "%I:%M%p").time(), arrival_times)
    arrival_times = list(map(lambda x: datetime.combine(search_date, x), at_conv))
    return arrival_times

# %% [markdown]
# Trying it for another flight on another day...

# %%
driver.get("http://flightaware.com/live/flight/AAL321/history/20170930/0130Z/KLGA/KORD")

# %%
soup2 = BeautifulSoup(driver.page_source, 'html.parser')

# %% [markdown]
# Target numbers here are:
# * Landing (actual) – 10:32 PM
# * Gate Arrival (actual) – 10:45 PM
# * Landing (sched) – 10:59 PM
# * Gate Arrival (sched) – 11:09 PM

# %%
for line in get_arrival_times("20170930", soup2):
    print(line)
# Out:
# *** 0.
#
# *** 1.
# View track log
# *** 2.
# Track inbound plane
# *** 3.
#
# All flights between LGA and ORD
#
# *** 4.
# 09:21PM EDT
# *** 5.
# 09:36PM EDT
# *** 6.
# 09:30PM EDT
# *** 7.
# 09:30PM EDT
# *** 8.
#
# 10:32PM CDT
#
#
# *** 9.
#
#
# 10:45PM CDT
#
#
#
# *** 10.
#
# 10:59PM CDT
#
#
#
# *** 11.
#
# 11:09PM CDT
#
#
# 2017-09-30 21:30:00
# 2017-09-30 22:32:00
# 2017-09-30 22:45:00
# 2017-09-30 22:59:00

# %% [markdown]
# **It's one off — searching `<span>` won't work!!!** There's an extra field (Track Inbound Plane) for recent entries that mucks it all up. Searching for this class instead. First the 8-24 flight:

# %%
for i, e in enumerate(details_sub1.find_all(class_="flightPageTimeData")):
    print(f"*** {i}.\n{e.text.strip()}")
# Out:
# *** 0.
# 09:25PM EDT
# *** 1.
# 33 minutes
# *** 2.
# 09:58PM EDT
# *** 3.
# 09:30PM EDT
# *** 4.
#
# *** 5.
# 09:30PM EDT
# *** 6.
# Less than 10 minutes
# *** 7.
#
# *** 8.
#
# *** 9.
# 10:56PM CDT
# *** 10.
# 5 minutes
# *** 11.
# 11:01PM CDT
# *** 12.
# 10:25PM CDT
# *** 13.
#
# *** 14.
# 11:09PM CDT
# *** 15.
#
# *** 16.
#
# *** 17.
# Less than 10 minutes

# %% [markdown]
# And then the 9-30 flight:

# %%
details2 = soup2.find(class_="flightPageDetails")
details_sub2 = details2.find(attrs={"data-template": "live/flight/details"})

# %%
for i, e in enumerate(details_sub2.find_all(class_="flightPageTimeData")):
    print(f"*** {i}.\n{e.text.strip()}")
# Out:
# *** 0.
# 09:21PM EDT
# *** 1.
# 15 minutes
# *** 2.
# 09:36PM EDT
# *** 3.
# 09:30PM EDT
# *** 4.
#
# *** 5.
# 09:30PM EDT
# *** 6.
# Less than 10 minutes
# *** 7.
#
# *** 8.
#
# *** 9.
# 10:32PM CDT
# *** 10.
# 13 minutes
# *** 11.
# 10:45PM CDT
# *** 12.
# 10:59PM CDT
# *** 13.
#
# *** 14.
# 11:09PM CDT
# *** 15.
#
# *** 16.
#
# *** 17.
# Less than 10 minutes

# %% [markdown]
# **These indices line up!!!** Take 2.

# %%
def get_arrival_times2(search_date_string, soup):
    search_date = datetime.strptime(search_date_string, "%Y%m%d").date()
    details = soup.find(class_="flightPageDetails")
    details_sub = details.find(attrs={"data-template": "live/flight/details"})
    spans = list(details_sub.find_all('span'))
    arrival_times = []
    fpTimeData = details_sub.find_all(class_="flightPageTimeData")
    # debugging
    for i, e in enumerate(fpTimeData):
        print(f"*** {i}.\n{e.text.strip()}")
    # carry on
    for i in [9,11,12,14]:
        time_str = fpTimeData[i].text.strip().split(' ')[0]
        arrival_times.append(time_str)
    at_conv = map(lambda x: datetime.strptime(x, "%I:%M%p").time(), arrival_times)
    arrival_times = list(map(lambda x: datetime.combine(search_date, x), at_conv))
    return arrival_times

# %% [markdown]
# Testing both flights:

# %%
for line in get_arrival_times2("20170824", soup1):
    print(line)
# Out:
# *** 0.
# 09:25PM EDT
# *** 1.
# 33 minutes
# *** 2.
# 09:58PM EDT
# *** 3.
# 09:30PM EDT
# *** 4.
#
# *** 5.
# 09:30PM EDT
# *** 6.
# Less than 10 minutes
# *** 7.
#
# *** 8.
#
# *** 9.
# 10:56PM CDT
# *** 10.
# 5 minutes
# *** 11.
# 11:01PM CDT
# *** 12.
# 10:25PM CDT
# *** 13.
#
# *** 14.
# 11:09PM CDT
# *** 15.
#
# *** 16.
#
# *** 17.
# Less than 10 minutes
# 2017-08-24 22:56:00
# 2017-08-24 23:01:00
# 2017-08-24 22:25:00
# 2017-08-24 23:09:00

# %%
for line in get_arrival_times2("20170930", soup2):
    print(line)
# Out:
# *** 0.
# 09:21PM EDT
# *** 1.
# 15 minutes
# *** 2.
# 09:36PM EDT
# *** 3.
# 09:30PM EDT
# *** 4.
#
# *** 5.
# 09:30PM EDT
# *** 6.
# Less than 10 minutes
# *** 7.
#
# *** 8.
#
# *** 9.
# 10:32PM CDT
# *** 10.
# 13 minutes
# *** 11.
# 10:45PM CDT
# *** 12.
# 10:59PM CDT
# *** 13.
#
# *** 14.
# 11:09PM CDT
# *** 15.
#
# *** 16.
#
# *** 17.
# Less than 10 minutes
# 2017-09-30 22:32:00
# 2017-09-30 22:45:00
# 2017-09-30 22:59:00
# 2017-09-30 23:09:00

# %% [markdown]
# **SUCCESS!!**

# %% [markdown]
# #### But first a better way to find out if a flight is canceled...

# %%
driver = webdriver.Chrome(chromedriver)

# %%
driver.get(canceled_url)

# %%
soup_can = BeautifulSoup(driver.page_source, 'html.parser')

# %%
'cancelled' in soup_can.find(class_="flightPageSummary").text.casefold()
# Out:
# True

# %% [markdown]
# Good... and then with a completed flight:

# %%
'cancelled' in soup2.find(class_="flightPageSummary").text.lower()
# Out:
# False

# %% [markdown]
# Success.

# %%
# run when ready to shut down the driver

driver.close()

# %% [markdown]
# #### Goal 2: scrape arrivals or route pages to find all flight numbers serving the route

# %% [markdown]
# *Not part of MVP*

# %% [markdown]
# #### Goal 3: build function that takes flight and route numbers and scrapes history for each

# %%
# All the LGA-ORD flights:

flight_urls = [
"http://flightaware.com/live/flight/AAL321/history/20171003/0130Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL371/history/20171003/0030Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL359/history/20171002/2330Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL361/history/20171002/2230Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL383/history/20171002/2200Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL345/history/20171002/2130Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL343/history/20171002/2030Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL358/history/20171002/1930Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL187/history/20171002/1830Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL332/history/20171002/1730Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL390/history/20171002/1630Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL337/history/20171002/1530Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL328/history/20171002/1430Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL373/history/20171002/1330Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL1619/history/20171002/1230Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL289/history/20171002/1130Z/KLGA/KORD",
"http://flightaware.com/live/flight/AAL304/history/20171002/1030Z/KLGA/KORD"
]

# %%
import re

# %%
flights = []
for url in flight_urls:
    fn_p = re.compile(r'AAL\d{3,4}')
    rn_p = re.compile(r'\d{4}Z')
    fn = fn_p.search(url).group()
    rn = rn_p.search(url).group()
    flights.append((fn,rn))

flights
# Out:
# [('AAL321', '0130Z'),
#  ('AAL371', '0030Z'),
#  ('AAL359', '2330Z'),
#  ('AAL361', '2230Z'),
#  ('AAL383', '2200Z'),
#  ('AAL345', '2130Z'),
#  ('AAL343', '2030Z'),
#  ('AAL358', '1930Z'),
#  ('AAL187', '1830Z'),
#  ('AAL332', '1730Z'),
#  ('AAL390', '1630Z'),
#  ('AAL337', '1530Z'),
#  ('AAL328', '1430Z'),
#  ('AAL373', '1330Z'),
#  ('AAL1619', '1230Z'),
#  ('AAL289', '1130Z'),
#  ('AAL304', '1030Z')]
